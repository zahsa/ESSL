# %%
import json
from collections import defaultdict
from itertools import chain
import pandas as pd
from mycolorpy import colorlist as mcp
from IPython.display import display, HTML

# %%
with open("/home/noah/ESSL/experiments/iteration_8/outcomes.json", "r") as f:
    results = json.load(f)

# %%
results.keys()
results['chromos']
# Out:
# [[0,
#   [['Contrast', 1.1492768005080465],
#    ['Solarize', 0],
#    ['ShearX', 0.04019175811474016]]],
#  [0,
#   [['ShearX', 0.09949716679064864],
#    ['Sharpness', 0.674961827968961],
#    ['Brightness', 0.24386505835638256]]],
#  [0,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [0,
#   [['Contrast', 1.1492768005080465],
#    ['Solarize', 0],
#    ['ShearX', 0.04019175811474016]]],
#  [0, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [0,
#   [['ShearY', 0.04990912373797426],
#    ['Brightness', 1.5534095536445602],
#    ['Contrast', 1.8058490636022833]]],
#  [0,
#   [['Contrast', 1.1492768005080465],
#    ['Solarize', 0],
#    ['ShearX', 0.04019175811474016]]],
#  [0,
#   [['Sharpness', 0.5806487233960831],
#    ['TranslateX', 4],
#    ['ShearY', 0.049481341973889655]]],
#  [0,
#   [['ShearY', 0.013366914735129909],
#    ['TranslateY', 13],
#    ['Color', 0.34964069787966523]]],
#  [0,
#   [['ShearY', 0.04990912373797426],
#    ['Brightness', 1.5534095536445602],
#    ['Contrast', 1.8058490636022833]]],
#  [0, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [0, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [0, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [0,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [0, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [0, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [1,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [1,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [1, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [1, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [1, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [1, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [1,
#   [['Contrast', 1.1492768005080465],
#    ['Solarize', 0],
#    ['ShearX', 0.04019175811474016]]],
#  [1, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [1, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [1,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [1, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [1,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [1, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [1,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [1, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [1, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [2,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [2, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [3, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [3, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [3, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [4, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [4, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [4,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [4,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [4, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [4, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [4,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [4, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [4,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [4, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5,
#   [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [5, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [5, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [6, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [6, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [6, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [7, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [7, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [8, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['Rotate', -1], ['Color', 1.482108065099183], ['TranslateX', 3]]],
#  [9, [['ShearY', 0.17017064305893717], ['TranslateX', 5], ['Solarize', 0]]]]

# %%
results['min']
# Out:
# [82.29, 82.37, 82.13, 82.05, 82.16, 82.14, 82.26, 82.41, 82.27, 82.15]

# %%
results['pop_vals']
# Out:
# [[0, 83.01],
#  [0, 83.59],
#  [0, 82.97],
#  [0, 83.43],
#  [0, 82.43],
#  [0, 83.28],
#  [0, 82.74],
#  [0, 82.29],
#  [0, 83.24],
#  [0, 83.36],
#  [0, 83.61],
#  [0, 83.61],
#  [0, 82.57],
#  [0, 83.9],
#  [0, 83.67],
#  [0, 83.67],
#  [1, 83.9],
#  [1, 83.9],
#  [1, 82.93],
#  [1, 83.25],
#  [1, 83.67],
#  [1, 83.67],
#  [1, 82.37],
#  [1, 83.21],
#  [1, 82.74],
#  [1, 82.7],
#  [1, 82.89],
#  [1, 83.57],
#  [1, 82.76],
#  [1, 83.33],
#  [1, 83.25],
#  [1, 83.03],
#  [2, 83.14],
#  [2, 82.96],
#  [2, 83.12],
#  [2, 82.79],
#  [2, 82.86],
#  [2, 82.98],
#  [2, 82.13],
#  [2, 83.25],
#  [2, 82.54],
#  [2, 83.65],
#  [2, 83.29],
#  [2, 82.43],
#  [2, 83.05],
#  [2, 82.41],
#  [2, 83.8],
#  [2, 82.52],
#  [3, 83.34],
#  [3, 83.99],
#  [3, 83.18],
#  [3, 82.89],
#  [3, 82.05],
#  [3, 82.93],
#  [3, 82.77],
#  [3, 82.9],
#  [3, 83.08],
#  [3, 82.48],
#  [3, 83.18],
#  [3, 83.15],
#  [3, 82.78],
#  [3, 83.4],
#  [3, 83.09],
#  [3, 83.18],
#  [4, 83.36],
#  [4, 83.1],
#  [4, 82.92],
#  [4, 82.99],
#  [4, 82.88],
#  [4, 83.24],
#  [4, 83.67],
#  [4, 83.2],
#  [4, 83.53],
#  [4, 82.4],
#  [4, 82.16],
#  [4, 82.93],
#  [4, 83.22],
#  [4, 83.54],
#  [4, 83.42],
#  [4, 83.78],
#  [5, 83.78],
#  [5, 82.83],
#  [5, 82.93],
#  [5, 82.71],
#  [5, 83.09],
#  [5, 83.0],
#  [5, 83.24],
#  [5, 82.23],
#  [5, 82.81],
#  [5, 82.86],
#  [5, 82.97],
#  [5, 82.14],
#  [5, 82.94],
#  [5, 83.12],
#  [5, 82.89],
#  [5, 82.89],
#  [6, 83.98],
#  [6, 83.17],
#  [6, 82.47],
#  [6, 82.68],
#  [6, 82.87],
#  [6, 82.63],
#  [6, 82.73],
#  [6, 83.87],
#  [6, 82.85],
#  [6, 83.05],
#  [6, 83.51],
#  [6, 83.5],
#  [6, 82.26],
#  [6, 82.8],
#  [6, 83.17],
#  [6, 82.9],
#  [7, 82.65],
#  [7, 82.64],
#  [7, 83.13],
#  [7, 83.81],
#  [7, 82.75],
#  [7, 83.29],
#  [7, 82.41],
#  [7, 83.08],
#  [7, 83.11],
#  [7, 83.83],
#  [7, 82.77],
#  [7, 83.16],
#  [7, 83.19],
#  [7, 83.93],
#  [7, 82.95],
#  [7, 83.18],
#  [8, 82.49],
#  [8, 83.02],
#  [8, 83.26],
#  [8, 82.97],
#  [8, 83.5],
#  [8, 82.93],
#  [8, 83.05],
#  [8, 82.61],
#  [8, 83.07],
#  [8, 83.34],
#  [8, 83.18],
#  [8, 82.27],
#  [8, 82.89],
#  [8, 82.78],
#  [8, 83.19],
#  [8, 83.19],
#  [9, 82.68],
#  [9, 82.28],
#  [9, 83.03],
#  [9, 82.37],
#  [9, 83.76],
#  [9, 82.62],
#  [9, 83.55],
#  [9, 82.9],
#  [9, 83.0],
#  [9, 82.61],
#  [9, 82.15],
#  [9, 82.76],
#  [9, 83.24],
#  [9, 83.02],
#  [9, 83.23],
#  [9, 82.33]]

# %%
# get max indexes from each generation
max_inds = defaultdict(list)

for i, val in results['pop_vals']:
    max_inds[i].append(val)
    
for k in max_inds:
    max_inds[k] = max_inds[k].index(max(max_inds[k]))
    
max_inds
# Out:
# defaultdict(list,
#             {0: 13, 1: 0, 2: 14, 3: 1, 4: 15, 5: 0, 6: 0, 7: 13, 8: 4, 9: 4})

# %%
results['chromos']

chromo_lists = defaultdict(list)

for c in results['chromos']:
    chromo_lists[c[0]].append(c[1])
# max_chromos = {c:chromo_lists[max_inds[c]] for c in chromo_lists}
# max_chromos
max_chromos = [chromo_lists[c][max_inds[c]] for c in max_inds]

# %%
max_chromos[1]
# Out:
# [['Sharpness', 1.8456105600533361], ['TranslateX', 3], ['TranslateY', 0]]

# %%
chromos = []
ops = []
for m in max_chromos:
    chromos.append(list(chain(*m)))
    ops.append(m[0][0])
    ops.append(m[1][0])
    ops.append(m[2][0])

colors=mcp.gen_color(cmap='Paired',n=len(ops))
chromo_colors = {op:color for op, color in zip(ops, colors)}

def colorchromos(val):
    return [f'Background: {chromo_colors[val["op1"]]}', 
            f'Background: white',
            f'Background: {chromo_colors[val["op2"]]}', 
            f'Background: white',
            f'Background: {chromo_colors[val["op3"]]}',
            f'Background: white']

df = pd.DataFrame(chromos, columns=["op1", "intensity1", 
                               "op2", "intensity2", 
                               "op3","intensity3"])

display(HTML(df.style.apply(colorchromos, axis=1).to_html()))
# Out:
# <style type="text/css">
# #T_87953_row0_col0, #T_87953_row1_col0, #T_87953_row2_col0 {
#   Background: #b2df8a;
# }
# #T_87953_row0_col1, #T_87953_row0_col3, #T_87953_row0_col5, #T_87953_row1_col1, #T_87953_row1_col3, #T_87953_row1_col5, #T_87953_row2_col1, #T_87953_row2_col3, #T_87953_row2_col5, #T_87953_row3_col1, #T_87953_row3_col3, #T_87953_row3_col5, #T_87953_row4_col1, #T_87953_row4_col3, #T_87953_row4_col5, #T_87953_row5_col1, #T_87953_row5_col3, #T_87953_row5_col5, #T_87953_row6_col1, #T_87953_row6_col3, #T_87953_row6_col5, #T_87953_row7_col1, #T_87953_row7_col3, #T_87953_row7_col5, #T_87953_row8_col1, #T_87953_row8_col3, #T_87953_row8_col5, #T_87953_row9_col1, #T_87953_row9_col3, #T_87953_row9_col5 {
#   Background: white;
# }
# #T_87953_row0_col2, #T_87953_row1_col2, #T_87953_row2_col2, #T_87953_row3_col2, #T_87953_row4_col2, #T_87953_row5_col2, #T_87953_row6_col0, #T_87953_row6_col2, #T_87953_row6_col4, #T_87953_row7_col0, #T_87953_row7_col2, #T_87953_row7_col4, #T_87953_row8_col0, #T_87953_row8_col2, #T_87953_row8_col4, #T_87953_row9_col0, #T_87953_row9_col2, #T_87953_row9_col4 {
#   Background: #b15928;
# }
# #T_87953_row0_col4, #T_87953_row1_col4, #T_87953_row2_col4 {
#   Background: #33a02c;
# }
# #T_87953_row3_col0, #T_87953_row4_col0, #T_87953_row5_col0 {
#   Background: #fdbf6f;
# }
# #T_87953_row3_col4, #T_87953_row4_col4, #T_87953_row5_col4 {
#   Background: #ff7f00;
# }
# </style>
# <table id="T_87953">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87953_level0_col0" class="col_heading level0 col0" >op1</th>
#       <th id="T_87953_level0_col1" class="col_heading level0 col1" >intensity1</th>
#       <th id="T_87953_level0_col2" class="col_heading level0 col2" >op2</th>
#       <th id="T_87953_level0_col3" class="col_heading level0 col3" >intensity2</th>
#       <th id="T_87953_level0_col4" class="col_heading level0 col4" >op3</th>
#       <th id="T_87953_level0_col5" class="col_heading level0 col5" >intensity3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87953_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87953_row0_col0" class="data row0 col0" >Sharpness</td>
#       <td id="T_87953_row0_col1" class="data row0 col1" >1.845611</td>
#       <td id="T_87953_row0_col2" class="data row0 col2" >TranslateX</td>
#       <td id="T_87953_row0_col3" class="data row0 col3" >3.000000</td>
#       <td id="T_87953_row0_col4" class="data row0 col4" >TranslateY</td>
#       <td id="T_87953_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87953_row1_col0" class="data row1 col0" >Sharpness</td>
#       <td id="T_87953_row1_col1" class="data row1 col1" >1.845611</td>
#       <td id="T_87953_row1_col2" class="data row1 col2" >TranslateX</td>
#       <td id="T_87953_row1_col3" class="data row1 col3" >3.000000</td>
#       <td id="T_87953_row1_col4" class="data row1 col4" >TranslateY</td>
#       <td id="T_87953_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87953_row2_col0" class="data row2 col0" >Sharpness</td>
#       <td id="T_87953_row2_col1" class="data row2 col1" >1.845611</td>
#       <td id="T_87953_row2_col2" class="data row2 col2" >TranslateX</td>
#       <td id="T_87953_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_87953_row2_col4" class="data row2 col4" >TranslateY</td>
#       <td id="T_87953_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87953_row3_col0" class="data row3 col0" >ShearY</td>
#       <td id="T_87953_row3_col1" class="data row3 col1" >0.170171</td>
#       <td id="T_87953_row3_col2" class="data row3 col2" >TranslateX</td>
#       <td id="T_87953_row3_col3" class="data row3 col3" >5.000000</td>
#       <td id="T_87953_row3_col4" class="data row3 col4" >Solarize</td>
#       <td id="T_87953_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87953_row4_col0" class="data row4 col0" >ShearY</td>
#       <td id="T_87953_row4_col1" class="data row4 col1" >0.170171</td>
#       <td id="T_87953_row4_col2" class="data row4 col2" >TranslateX</td>
#       <td id="T_87953_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_87953_row4_col4" class="data row4 col4" >Solarize</td>
#       <td id="T_87953_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87953_row5_col0" class="data row5 col0" >ShearY</td>
#       <td id="T_87953_row5_col1" class="data row5 col1" >0.170171</td>
#       <td id="T_87953_row5_col2" class="data row5 col2" >TranslateX</td>
#       <td id="T_87953_row5_col3" class="data row5 col3" >5.000000</td>
#       <td id="T_87953_row5_col4" class="data row5 col4" >Solarize</td>
#       <td id="T_87953_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87953_row6_col0" class="data row6 col0" >Rotate</td>
#       <td id="T_87953_row6_col1" class="data row6 col1" >-1.000000</td>
#       <td id="T_87953_row6_col2" class="data row6 col2" >Color</td>
#       <td id="T_87953_row6_col3" class="data row6 col3" >1.482108</td>
#       <td id="T_87953_row6_col4" class="data row6 col4" >TranslateX</td>
#       <td id="T_87953_row6_col5" class="data row6 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_87953_row7_col0" class="data row7 col0" >Rotate</td>
#       <td id="T_87953_row7_col1" class="data row7 col1" >-1.000000</td>
#       <td id="T_87953_row7_col2" class="data row7 col2" >Color</td>
#       <td id="T_87953_row7_col3" class="data row7 col3" >1.482108</td>
#       <td id="T_87953_row7_col4" class="data row7 col4" >TranslateX</td>
#       <td id="T_87953_row7_col5" class="data row7 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_87953_row8_col0" class="data row8 col0" >Rotate</td>
#       <td id="T_87953_row8_col1" class="data row8 col1" >-1.000000</td>
#       <td id="T_87953_row8_col2" class="data row8 col2" >Color</td>
#       <td id="T_87953_row8_col3" class="data row8 col3" >1.482108</td>
#       <td id="T_87953_row8_col4" class="data row8 col4" >TranslateX</td>
#       <td id="T_87953_row8_col5" class="data row8 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_87953_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_87953_row9_col0" class="data row9 col0" >Rotate</td>
#       <td id="T_87953_row9_col1" class="data row9 col1" >-1.000000</td>
#       <td id="T_87953_row9_col2" class="data row9 col2" >Color</td>
#       <td id="T_87953_row9_col3" class="data row9 col3" >1.482108</td>
#       <td id="T_87953_row9_col4" class="data row9 col4" >TranslateX</td>
#       <td id="T_87953_row9_col5" class="data row9 col5" >3</td>
#     </tr>
#   </tbody>
# </table>
