# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
import os
import json
import numpy as np
from collections import defaultdict
from IPython.display import display, HTML

from matplotlib import colors as mcolors
from matplotlib import cm
from mycolorpy import colorlist as mcp

# %%
dirs = ["/home/noah/ESSL/experiments/ssl_testing2/BYOL",
        "/home/noah/ESSL/experiments/ssl_testing2/NNCLR",
        "/home/noah/ESSL/experiments/ssl_testing2/SimCLR",
        "/home/noah/ESSL/experiments/ssl_testing2/SwaV"]

# vals = pd.read_csv(os.path.join(dirs[0], "outcomes.csv"))
vals = pd.DataFrame(columns=pd.read_csv(os.path.join(dirs[0], "outcomes.csv")).columns)
for d in dirs:
    f = os.path.join(d, "outcomes.csv")
    f = pd.read_csv(f)
    f["method"] = [os.path.basename(d) for _ in range(len(f))]
    vals = pd.concat([vals, f])

chromo_df = pd.DataFrame()
with open(os.path.join(dirs[0], "chromosomes.json"), "r") as f:
    chromos = json.load(f)
c_strings = []
for i in range(len(chromos)):
    c = chromos[str(i)]
    c = [c_i[0] for c_i in c]
    c_strings.append(" ".join(c))
colors=mcp.gen_color(cmap='Paired',n=len(c_strings))
chromo_colors = {chromo:color for chromo, color in zip(c_strings, colors)}
chromo_df["chromosome"] = c_strings
chromo_colors
# Out:
# {'Sharpness ShearX Posterize': '#a6cee3',
#  'Solarize Rotate TranslateX': '#1f78b4',
#  'Color ShearY TranslateY': '#b2df8a',
#  'ShearX Posterize TranslateX': '#fb9a99',
#  'Rotate Brightness Solarize': '#e31a1c',
#  'TranslateX Solarize TranslateY': '#fdbf6f',
#  'Sharpness ShearX TranslateY': '#cab2d6',
#  'Contrast Color TranslateY': '#6a3d9a',
#  'Solarize ShearY Color': '#ffff99',
#  'TranslateY ShearX Sharpness': '#b15928'}

# %%
def colorchromos(val):
    return [f'Background: {chromo_colors[val["chromosome"]]}' for _ in range(len(val))]

# %%
for d in dirs:
    try:
        f = os.path.join(d, "outcomes.csv")
        f = pd.read_csv(f)
        method = os.path.basename(d)
        chromo_df[f"{method} test acc"] = f["test acc"]
        chromo_df[f"{method} test loss"] = f["final test loss"]
    except KeyError:
        continue
        
chromo_df = chromo_df.reindex(columns=["chromosome"]+[c for c in chromo_df.columns if "acc" in c] + [c for c in chromo_df.columns if "loss" in c])
chromo_df
vals["chromosome"] = vals["chromosome"].apply(lambda x: c_strings[int(x)])
vals[["chromosome", "method", "test acc", "final test loss"]]
chromo_df.style.apply(colorchromos, axis=0)

for col in [c for c in chromo_df if c != "chromosome"]:
    chromo_df = chromo_df.sort_values(by=col, ascending=False)
    display(HTML(chromo_df[["chromosome", col]].style.apply(colorchromos, axis=1).to_html()))
# Out:
# <style type="text/css">
# #T_8dd4a_row0_col0, #T_8dd4a_row0_col1 {
#   Background: #fb9a99;
# }
# #T_8dd4a_row1_col0, #T_8dd4a_row1_col1 {
#   Background: #e31a1c;
# }
# #T_8dd4a_row2_col0, #T_8dd4a_row2_col1 {
#   Background: #6a3d9a;
# }
# #T_8dd4a_row3_col0, #T_8dd4a_row3_col1 {
#   Background: #ffff99;
# }
# #T_8dd4a_row4_col0, #T_8dd4a_row4_col1 {
#   Background: #a6cee3;
# }
# #T_8dd4a_row5_col0, #T_8dd4a_row5_col1 {
#   Background: #b15928;
# }
# #T_8dd4a_row6_col0, #T_8dd4a_row6_col1 {
#   Background: #b2df8a;
# }
# #T_8dd4a_row7_col0, #T_8dd4a_row7_col1 {
#   Background: #cab2d6;
# }
# #T_8dd4a_row8_col0, #T_8dd4a_row8_col1 {
#   Background: #1f78b4;
# }
# #T_8dd4a_row9_col0, #T_8dd4a_row9_col1 {
#   Background: #fdbf6f;
# }
# </style>
# <table id="T_8dd4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dd4a_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_8dd4a_level0_col1" class="col_heading level0 col1" >BYOL test acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dd4a_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_8dd4a_row0_col0" class="data row0 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_8dd4a_row0_col1" class="data row0 col1" >83.780000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_8dd4a_row1_col0" class="data row1 col0" >Rotate Brightness Solarize</td>
#       <td id="T_8dd4a_row1_col1" class="data row1 col1" >83.720000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_8dd4a_row2_col0" class="data row2 col0" >Contrast Color TranslateY</td>
#       <td id="T_8dd4a_row2_col1" class="data row2 col1" >83.600000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_8dd4a_row3_col0" class="data row3 col0" >Solarize ShearY Color</td>
#       <td id="T_8dd4a_row3_col1" class="data row3 col1" >83.570000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_8dd4a_row4_col0" class="data row4 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_8dd4a_row4_col1" class="data row4 col1" >83.420000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_8dd4a_row5_col0" class="data row5 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_8dd4a_row5_col1" class="data row5 col1" >83.160000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_8dd4a_row6_col0" class="data row6 col0" >Color ShearY TranslateY</td>
#       <td id="T_8dd4a_row6_col1" class="data row6 col1" >82.990000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_8dd4a_row7_col0" class="data row7 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_8dd4a_row7_col1" class="data row7 col1" >82.770000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_8dd4a_row8_col0" class="data row8 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_8dd4a_row8_col1" class="data row8 col1" >82.740000</td>
#     </tr>
#     <tr>
#       <th id="T_8dd4a_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_8dd4a_row9_col0" class="data row9 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_8dd4a_row9_col1" class="data row9 col1" >82.500000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_45c71_row0_col0, #T_45c71_row0_col1 {
#   Background: #fdbf6f;
# }
# #T_45c71_row1_col0, #T_45c71_row1_col1 {
#   Background: #1f78b4;
# }
# #T_45c71_row2_col0, #T_45c71_row2_col1 {
#   Background: #6a3d9a;
# }
# #T_45c71_row3_col0, #T_45c71_row3_col1 {
#   Background: #fb9a99;
# }
# #T_45c71_row4_col0, #T_45c71_row4_col1 {
#   Background: #b2df8a;
# }
# #T_45c71_row5_col0, #T_45c71_row5_col1 {
#   Background: #cab2d6;
# }
# #T_45c71_row6_col0, #T_45c71_row6_col1 {
#   Background: #ffff99;
# }
# #T_45c71_row7_col0, #T_45c71_row7_col1 {
#   Background: #b15928;
# }
# #T_45c71_row8_col0, #T_45c71_row8_col1 {
#   Background: #e31a1c;
# }
# #T_45c71_row9_col0, #T_45c71_row9_col1 {
#   Background: #a6cee3;
# }
# </style>
# <table id="T_45c71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45c71_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_45c71_level0_col1" class="col_heading level0 col1" >NNCLR test acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45c71_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_45c71_row0_col0" class="data row0 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_45c71_row0_col1" class="data row0 col1" >83.740000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_45c71_row1_col0" class="data row1 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_45c71_row1_col1" class="data row1 col1" >82.830000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_45c71_row2_col0" class="data row2 col0" >Contrast Color TranslateY</td>
#       <td id="T_45c71_row2_col1" class="data row2 col1" >82.690000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_45c71_row3_col0" class="data row3 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_45c71_row3_col1" class="data row3 col1" >82.590000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_45c71_row4_col0" class="data row4 col0" >Color ShearY TranslateY</td>
#       <td id="T_45c71_row4_col1" class="data row4 col1" >82.510000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_45c71_row5_col0" class="data row5 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_45c71_row5_col1" class="data row5 col1" >82.480000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_45c71_row6_col0" class="data row6 col0" >Solarize ShearY Color</td>
#       <td id="T_45c71_row6_col1" class="data row6 col1" >82.460000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_45c71_row7_col0" class="data row7 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_45c71_row7_col1" class="data row7 col1" >82.310000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_45c71_row8_col0" class="data row8 col0" >Rotate Brightness Solarize</td>
#       <td id="T_45c71_row8_col1" class="data row8 col1" >82.120000</td>
#     </tr>
#     <tr>
#       <th id="T_45c71_level0_row9" class="row_heading level0 row9" >0</th>
#       <td id="T_45c71_row9_col0" class="data row9 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_45c71_row9_col1" class="data row9 col1" >82.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3fa93_row0_col0, #T_3fa93_row0_col1 {
#   Background: #b2df8a;
# }
# #T_3fa93_row1_col0, #T_3fa93_row1_col1 {
#   Background: #1f78b4;
# }
# #T_3fa93_row2_col0, #T_3fa93_row2_col1 {
#   Background: #6a3d9a;
# }
# #T_3fa93_row3_col0, #T_3fa93_row3_col1 {
#   Background: #fb9a99;
# }
# #T_3fa93_row4_col0, #T_3fa93_row4_col1 {
#   Background: #e31a1c;
# }
# #T_3fa93_row5_col0, #T_3fa93_row5_col1 {
#   Background: #cab2d6;
# }
# #T_3fa93_row6_col0, #T_3fa93_row6_col1 {
#   Background: #a6cee3;
# }
# #T_3fa93_row7_col0, #T_3fa93_row7_col1 {
#   Background: #b15928;
# }
# #T_3fa93_row8_col0, #T_3fa93_row8_col1 {
#   Background: #ffff99;
# }
# #T_3fa93_row9_col0, #T_3fa93_row9_col1 {
#   Background: #fdbf6f;
# }
# </style>
# <table id="T_3fa93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fa93_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_3fa93_level0_col1" class="col_heading level0 col1" >SimCLR test acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fa93_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_3fa93_row0_col0" class="data row0 col0" >Color ShearY TranslateY</td>
#       <td id="T_3fa93_row0_col1" class="data row0 col1" >82.920000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fa93_row1_col0" class="data row1 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_3fa93_row1_col1" class="data row1 col1" >82.760000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row2" class="row_heading level0 row2" >7</th>
#       <td id="T_3fa93_row2_col0" class="data row2 col0" >Contrast Color TranslateY</td>
#       <td id="T_3fa93_row2_col1" class="data row2 col1" >82.750000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3fa93_row3_col0" class="data row3 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_3fa93_row3_col1" class="data row3 col1" >82.330000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3fa93_row4_col0" class="data row4 col0" >Rotate Brightness Solarize</td>
#       <td id="T_3fa93_row4_col1" class="data row4 col1" >82.270000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_3fa93_row5_col0" class="data row5 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_3fa93_row5_col1" class="data row5 col1" >82.190000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_3fa93_row6_col0" class="data row6 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_3fa93_row6_col1" class="data row6 col1" >82.140000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_3fa93_row7_col0" class="data row7 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_3fa93_row7_col1" class="data row7 col1" >81.720000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3fa93_row8_col0" class="data row8 col0" >Solarize ShearY Color</td>
#       <td id="T_3fa93_row8_col1" class="data row8 col1" >81.530000</td>
#     </tr>
#     <tr>
#       <th id="T_3fa93_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_3fa93_row9_col0" class="data row9 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_3fa93_row9_col1" class="data row9 col1" >81.500000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5c5a4_row0_col0, #T_5c5a4_row0_col1 {
#   Background: #b2df8a;
# }
# #T_5c5a4_row1_col0, #T_5c5a4_row1_col1 {
#   Background: #1f78b4;
# }
# #T_5c5a4_row2_col0, #T_5c5a4_row2_col1 {
#   Background: #cab2d6;
# }
# #T_5c5a4_row3_col0, #T_5c5a4_row3_col1 {
#   Background: #b15928;
# }
# #T_5c5a4_row4_col0, #T_5c5a4_row4_col1 {
#   Background: #ffff99;
# }
# #T_5c5a4_row5_col0, #T_5c5a4_row5_col1 {
#   Background: #a6cee3;
# }
# #T_5c5a4_row6_col0, #T_5c5a4_row6_col1 {
#   Background: #fdbf6f;
# }
# #T_5c5a4_row7_col0, #T_5c5a4_row7_col1 {
#   Background: #6a3d9a;
# }
# #T_5c5a4_row8_col0, #T_5c5a4_row8_col1 {
#   Background: #e31a1c;
# }
# #T_5c5a4_row9_col0, #T_5c5a4_row9_col1 {
#   Background: #fb9a99;
# }
# </style>
# <table id="T_5c5a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c5a4_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_5c5a4_level0_col1" class="col_heading level0 col1" >SwaV test acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c5a4_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_5c5a4_row0_col0" class="data row0 col0" >Color ShearY TranslateY</td>
#       <td id="T_5c5a4_row0_col1" class="data row0 col1" >82.940000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c5a4_row1_col0" class="data row1 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_5c5a4_row1_col1" class="data row1 col1" >82.860000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_5c5a4_row2_col0" class="data row2 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_5c5a4_row2_col1" class="data row2 col1" >82.810000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_5c5a4_row3_col0" class="data row3 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_5c5a4_row3_col1" class="data row3 col1" >82.610000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_5c5a4_row4_col0" class="data row4 col0" >Solarize ShearY Color</td>
#       <td id="T_5c5a4_row4_col1" class="data row4 col1" >82.510000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_5c5a4_row5_col0" class="data row5 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_5c5a4_row5_col1" class="data row5 col1" >82.460000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_5c5a4_row6_col0" class="data row6 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_5c5a4_row6_col1" class="data row6 col1" >82.440000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5c5a4_row7_col0" class="data row7 col0" >Contrast Color TranslateY</td>
#       <td id="T_5c5a4_row7_col1" class="data row7 col1" >82.280000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_5c5a4_row8_col0" class="data row8 col0" >Rotate Brightness Solarize</td>
#       <td id="T_5c5a4_row8_col1" class="data row8 col1" >82.020000</td>
#     </tr>
#     <tr>
#       <th id="T_5c5a4_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_5c5a4_row9_col0" class="data row9 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_5c5a4_row9_col1" class="data row9 col1" >81.980000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0eb28_row0_col0, #T_0eb28_row0_col1 {
#   Background: #fdbf6f;
# }
# #T_0eb28_row1_col0, #T_0eb28_row1_col1 {
#   Background: #cab2d6;
# }
# #T_0eb28_row2_col0, #T_0eb28_row2_col1 {
#   Background: #1f78b4;
# }
# #T_0eb28_row3_col0, #T_0eb28_row3_col1 {
#   Background: #a6cee3;
# }
# #T_0eb28_row4_col0, #T_0eb28_row4_col1 {
#   Background: #b2df8a;
# }
# #T_0eb28_row5_col0, #T_0eb28_row5_col1 {
#   Background: #e31a1c;
# }
# #T_0eb28_row6_col0, #T_0eb28_row6_col1 {
#   Background: #ffff99;
# }
# #T_0eb28_row7_col0, #T_0eb28_row7_col1 {
#   Background: #6a3d9a;
# }
# #T_0eb28_row8_col0, #T_0eb28_row8_col1 {
#   Background: #b15928;
# }
# #T_0eb28_row9_col0, #T_0eb28_row9_col1 {
#   Background: #fb9a99;
# }
# </style>
# <table id="T_0eb28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0eb28_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_0eb28_level0_col1" class="col_heading level0 col1" >BYOL test loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0eb28_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_0eb28_row0_col0" class="data row0 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_0eb28_row0_col1" class="data row0 col1" >0.519599</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_0eb28_row1_col0" class="data row1 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_0eb28_row1_col1" class="data row1 col1" >0.515354</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_0eb28_row2_col0" class="data row2 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_0eb28_row2_col1" class="data row2 col1" >0.511567</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_0eb28_row3_col0" class="data row3 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_0eb28_row3_col1" class="data row3 col1" >0.507513</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_0eb28_row4_col0" class="data row4 col0" >Color ShearY TranslateY</td>
#       <td id="T_0eb28_row4_col1" class="data row4 col1" >0.505628</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_0eb28_row5_col0" class="data row5 col0" >Rotate Brightness Solarize</td>
#       <td id="T_0eb28_row5_col1" class="data row5 col1" >0.494973</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_0eb28_row6_col0" class="data row6 col0" >Solarize ShearY Color</td>
#       <td id="T_0eb28_row6_col1" class="data row6 col1" >0.492091</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0eb28_row7_col0" class="data row7 col0" >Contrast Color TranslateY</td>
#       <td id="T_0eb28_row7_col1" class="data row7 col1" >0.490933</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_0eb28_row8_col0" class="data row8 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_0eb28_row8_col1" class="data row8 col1" >0.487975</td>
#     </tr>
#     <tr>
#       <th id="T_0eb28_level0_row9" class="row_heading level0 row9" >3</th>
#       <td id="T_0eb28_row9_col0" class="data row9 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_0eb28_row9_col1" class="data row9 col1" >0.485341</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ee112_row0_col0, #T_ee112_row0_col1 {
#   Background: #a6cee3;
# }
# #T_ee112_row1_col0, #T_ee112_row1_col1 {
#   Background: #b15928;
# }
# #T_ee112_row2_col0, #T_ee112_row2_col1 {
#   Background: #cab2d6;
# }
# #T_ee112_row3_col0, #T_ee112_row3_col1 {
#   Background: #e31a1c;
# }
# #T_ee112_row4_col0, #T_ee112_row4_col1 {
#   Background: #fb9a99;
# }
# #T_ee112_row5_col0, #T_ee112_row5_col1 {
#   Background: #b2df8a;
# }
# #T_ee112_row6_col0, #T_ee112_row6_col1 {
#   Background: #1f78b4;
# }
# #T_ee112_row7_col0, #T_ee112_row7_col1 {
#   Background: #ffff99;
# }
# #T_ee112_row8_col0, #T_ee112_row8_col1 {
#   Background: #6a3d9a;
# }
# #T_ee112_row9_col0, #T_ee112_row9_col1 {
#   Background: #fdbf6f;
# }
# </style>
# <table id="T_ee112">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee112_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_ee112_level0_col1" class="col_heading level0 col1" >NNCLR test loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee112_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee112_row0_col0" class="data row0 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_ee112_row0_col1" class="data row0 col1" >0.537182</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_ee112_row1_col0" class="data row1 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_ee112_row1_col1" class="data row1 col1" >0.530363</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_ee112_row2_col0" class="data row2 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_ee112_row2_col1" class="data row2 col1" >0.523048</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ee112_row3_col0" class="data row3 col0" >Rotate Brightness Solarize</td>
#       <td id="T_ee112_row3_col1" class="data row3 col1" >0.522890</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_ee112_row4_col0" class="data row4 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_ee112_row4_col1" class="data row4 col1" >0.519442</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_ee112_row5_col0" class="data row5 col0" >Color ShearY TranslateY</td>
#       <td id="T_ee112_row5_col1" class="data row5 col1" >0.517508</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_ee112_row6_col0" class="data row6 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_ee112_row6_col1" class="data row6 col1" >0.517258</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ee112_row7_col0" class="data row7 col0" >Solarize ShearY Color</td>
#       <td id="T_ee112_row7_col1" class="data row7 col1" >0.511206</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_ee112_row8_col0" class="data row8 col0" >Contrast Color TranslateY</td>
#       <td id="T_ee112_row8_col1" class="data row8 col1" >0.508019</td>
#     </tr>
#     <tr>
#       <th id="T_ee112_level0_row9" class="row_heading level0 row9" >5</th>
#       <td id="T_ee112_row9_col0" class="data row9 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_ee112_row9_col1" class="data row9 col1" >0.487539</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_13ccf_row0_col0, #T_13ccf_row0_col1 {
#   Background: #fdbf6f;
# }
# #T_13ccf_row1_col0, #T_13ccf_row1_col1 {
#   Background: #ffff99;
# }
# #T_13ccf_row2_col0, #T_13ccf_row2_col1 {
#   Background: #b15928;
# }
# #T_13ccf_row3_col0, #T_13ccf_row3_col1 {
#   Background: #e31a1c;
# }
# #T_13ccf_row4_col0, #T_13ccf_row4_col1 {
#   Background: #fb9a99;
# }
# #T_13ccf_row5_col0, #T_13ccf_row5_col1 {
#   Background: #a6cee3;
# }
# #T_13ccf_row6_col0, #T_13ccf_row6_col1 {
#   Background: #6a3d9a;
# }
# #T_13ccf_row7_col0, #T_13ccf_row7_col1 {
#   Background: #cab2d6;
# }
# #T_13ccf_row8_col0, #T_13ccf_row8_col1 {
#   Background: #1f78b4;
# }
# #T_13ccf_row9_col0, #T_13ccf_row9_col1 {
#   Background: #b2df8a;
# }
# </style>
# <table id="T_13ccf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13ccf_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_13ccf_level0_col1" class="col_heading level0 col1" >SimCLR test loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13ccf_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_13ccf_row0_col0" class="data row0 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_13ccf_row0_col1" class="data row0 col1" >0.555535</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_13ccf_row1_col0" class="data row1 col0" >Solarize ShearY Color</td>
#       <td id="T_13ccf_row1_col1" class="data row1 col1" >0.547603</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_13ccf_row2_col0" class="data row2 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_13ccf_row2_col1" class="data row2 col1" >0.543455</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_13ccf_row3_col0" class="data row3 col0" >Rotate Brightness Solarize</td>
#       <td id="T_13ccf_row3_col1" class="data row3 col1" >0.534600</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_13ccf_row4_col0" class="data row4 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_13ccf_row4_col1" class="data row4 col1" >0.534375</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_13ccf_row5_col0" class="data row5 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_13ccf_row5_col1" class="data row5 col1" >0.530355</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_13ccf_row6_col0" class="data row6 col0" >Contrast Color TranslateY</td>
#       <td id="T_13ccf_row6_col1" class="data row6 col1" >0.530051</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_13ccf_row7_col0" class="data row7 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_13ccf_row7_col1" class="data row7 col1" >0.522471</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_13ccf_row8_col0" class="data row8 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_13ccf_row8_col1" class="data row8 col1" >0.521195</td>
#     </tr>
#     <tr>
#       <th id="T_13ccf_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_13ccf_row9_col0" class="data row9 col0" >Color ShearY TranslateY</td>
#       <td id="T_13ccf_row9_col1" class="data row9 col1" >0.518788</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_742dc_row0_col0, #T_742dc_row0_col1 {
#   Background: #6a3d9a;
# }
# #T_742dc_row1_col0, #T_742dc_row1_col1 {
#   Background: #e31a1c;
# }
# #T_742dc_row2_col0, #T_742dc_row2_col1 {
#   Background: #fb9a99;
# }
# #T_742dc_row3_col0, #T_742dc_row3_col1 {
#   Background: #a6cee3;
# }
# #T_742dc_row4_col0, #T_742dc_row4_col1 {
#   Background: #fdbf6f;
# }
# #T_742dc_row5_col0, #T_742dc_row5_col1 {
#   Background: #cab2d6;
# }
# #T_742dc_row6_col0, #T_742dc_row6_col1 {
#   Background: #b2df8a;
# }
# #T_742dc_row7_col0, #T_742dc_row7_col1 {
#   Background: #b15928;
# }
# #T_742dc_row8_col0, #T_742dc_row8_col1 {
#   Background: #ffff99;
# }
# #T_742dc_row9_col0, #T_742dc_row9_col1 {
#   Background: #1f78b4;
# }
# </style>
# <table id="T_742dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_742dc_level0_col0" class="col_heading level0 col0" >chromosome</th>
#       <th id="T_742dc_level0_col1" class="col_heading level0 col1" >SwaV test loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_742dc_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_742dc_row0_col0" class="data row0 col0" >Contrast Color TranslateY</td>
#       <td id="T_742dc_row0_col1" class="data row0 col1" >0.540769</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_742dc_row1_col0" class="data row1 col0" >Rotate Brightness Solarize</td>
#       <td id="T_742dc_row1_col1" class="data row1 col1" >0.539104</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_742dc_row2_col0" class="data row2 col0" >ShearX Posterize TranslateX</td>
#       <td id="T_742dc_row2_col1" class="data row2 col1" >0.526966</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_742dc_row3_col0" class="data row3 col0" >Sharpness ShearX Posterize</td>
#       <td id="T_742dc_row3_col1" class="data row3 col1" >0.524414</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_742dc_row4_col0" class="data row4 col0" >TranslateX Solarize TranslateY</td>
#       <td id="T_742dc_row4_col1" class="data row4 col1" >0.517162</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_742dc_row5_col0" class="data row5 col0" >Sharpness ShearX TranslateY</td>
#       <td id="T_742dc_row5_col1" class="data row5 col1" >0.516830</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_742dc_row6_col0" class="data row6 col0" >Color ShearY TranslateY</td>
#       <td id="T_742dc_row6_col1" class="data row6 col1" >0.512359</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_742dc_row7_col0" class="data row7 col0" >TranslateY ShearX Sharpness</td>
#       <td id="T_742dc_row7_col1" class="data row7 col1" >0.511747</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_742dc_row8_col0" class="data row8 col0" >Solarize ShearY Color</td>
#       <td id="T_742dc_row8_col1" class="data row8 col1" >0.511014</td>
#     </tr>
#     <tr>
#       <th id="T_742dc_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_742dc_row9_col0" class="data row9 col0" >Solarize Rotate TranslateX</td>
#       <td id="T_742dc_row9_col1" class="data row9 col1" >0.508731</td>
#     </tr>
#   </tbody>
# </table>

# %%
chromosomes = []
for d in dirs:
    with open(os.path.join(d, "chromosomes.json"), "r") as f:
        chromosomes.append(json.load(f))
# confrim that we used the same chromosomes
for c1 in chromosomes:
    for c2 in chromosomes:
        print(c1 == c2)
        
len(chromosomes)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# 4

# %% [markdown]
# I realize now that because we are using the same random seed, we get the exact same outcome everytime for all 4 experiments.

# %%
# sort based on test acc and test loss and then compute the distance matrix between chromosomes for each method
accuracies = [c for c in chromo_df.columns if "acc" in c]
accuracies
# Out:
# ['BYOL test acc', 'NNCLR test acc', 'SimCLR test acc', 'SwaV test acc']

# %%
normalization = {
    "ShearX":[0.0, 0.3],
    "ShearY":[0.0, 0.3],
    "TranslateX":[0, int(150 / 331.0 * 32)],
    "TranslateY":[0, int(150 / 331.0 * 32)],
    "Rotate":[-30, 30],
    "Color":[0.1, 1.9],
    "Posterize":[4, 8],
    "Solarize":[0, 1],
    "Contrast":[0.1,1.9],
    "Sharpness":[0.1, 1.9],
    "Brightness":[0.1, 1.9]
}

def chromo_distance(c1, c2):
    # hammming distance plus intensity differnece
    eq = np.array([int(c1_i[0] == c2_i[0]) for c1_i, c2_i in zip(c1, c2)])
    c1_i = np.array([c[1] for c in c1])
    c2_i = np.array([c[1] for c in c2])
    return sum(eq * np.abs(c2_i - c1_i))

def chromo_distance2(c1, c2, normalization=normalization):
    # intensity difference
    distance = 0
    for c1_i in c1:
        for c2_i in c2:
            if c1_i[0] == c2_i[0]:
                distance+= 1-abs(normalize(c1_i, normalization)[1] - normalize(c2_i, normalization)[1])

    return distance

def chromo_distance3(c1, c2):
    # number of same operators
    similarity = 0
    for c1_i in c1:
        for c2_i in c2:
            if c1_i[0] == c2_i[0]:
                similarity += 1
    return similarity


def normalize(c, normalization):
    return [c[0], (c[1] - normalization[c[0]][0]) / (normalization[c[0]][1] - normalization[c[0]][0])]



# sort based on accuracy and visualzie difference in chromosomes
for acc in accuracies:
    chromo_df = chromo_df.sort_values(by=acc)
    inds = chromo_df.index
    dist_mat = []
    for i in inds:
        dist_row = []
        for j in inds:
            c1 = chromos[str(i)]
            c2 = chromos[str(j)]
            dist_row.append(chromo_distance3(c1, c2))
        dist_mat.append(dist_row)
    sns.heatmap(data=dist_mat, xticklabels=inds, yticklabels=inds, cmap="YlGnBu")
    plt.suptitle(acc)
    plt.show()
    plt.clf()

# %%
for col in [c for c in vals.columns if ("loss" in c or "acc" in c)]:
    plt.clf()
    sns.boxplot(data=vals, x="method", y=col)
    plt.show()
