# %%
import json
import pandas as pd
import glob
import os
from itertools import chain
import numpy as np

# %%
exp_dir = "/home/noah/ESSL/exps/iteration4/exp6_1"
coeffs = []
exps = glob.glob(os.path.join(exp_dir, "*/"))
chromos = []
for e in exps:
    seed = e.split("/")[-2]
    with open(os.path.join(e, "outcomes.json"), "r") as f:
        results = json.load(f)
        for fitness, chromo in zip(results["pop_vals"], results["chromos"]):
            c = list(chain.from_iterable(chromo[1]))
            c.append(seed)
            c.append(fitness[1])
            chromos.append(c)
columns = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
columns.append("seed")
columns.append("test acc")
columns

df = pd.DataFrame(chromos, columns=columns)
ops = set(list(df["aug1"]) + list(df["aug2"]) +  list(df["aug3"]))
indexes = {op:i for i, op in enumerate(ops)}
chromos_long = np.zeros([len(chromos), len(ops)+2])

for i, c in enumerate(chromos):
    for aug, intensity in zip(c[:-2][::2], c[:-2][1::2]):
        chromos_long[i][indexes[aug]] = intensity
        chromos_long[i][-2] = int(c[-2])
        chromos_long[i][-1] = c[-1]

columns_long = list(ops) + ["seed", "fitness"]
df_long = pd.DataFrame(chromos_long, columns = columns_long)
df_long
ops
df_long
# Out:
#      Contrast  Solarize  TranslateY     Color  VerticalFlip  HorizontalFlip  \
# 0         0.0  0.000000         2.0  0.000000      0.000000        0.000000
# 1         0.0  0.000000         0.0  0.000000      0.000000        0.603191
# 2         0.0  0.000000         0.0  0.469010      0.981939        0.000000
# 3         0.0  0.428321         0.0  0.953488      0.000000        0.000000
# 4         0.0  0.000000         0.0  0.443667      0.000000        0.000000
# ..        ...       ...         ...       ...           ...             ...
# 445       0.0  0.000000         0.0  0.594466      0.850476        0.000000
# 446       0.0  0.813661         0.0  0.000000      0.000000        0.000000
# 447       0.0  0.000000         3.0  0.000000      0.850476        0.000000
# 448       0.0  0.000000         2.0  0.000000      0.000000        0.000000
# 449       0.0  0.000000         0.0  0.161926      0.000000        0.000000
#
#      Brightness  Rotate  Sharpness  TranslateX    ShearX    ShearY  seed  \
# 0      0.000000    22.0   0.000000         7.0  0.000000  0.000000   7.0
# 1      1.314937     0.0   0.000000         0.0  0.000000  0.126119   7.0
# 2      0.000000     0.0   0.000000         0.0  0.041533  0.000000   7.0
# 3      0.000000     0.0   0.668222         0.0  0.000000  0.000000   7.0
# 4      0.000000     0.0   0.000000        10.0  0.136720  0.000000   7.0
# ..          ...     ...        ...         ...       ...       ...   ...
# 445    0.000000     0.0   0.000000         0.0  0.104604  0.000000   8.0
# 446    0.918928     0.0   0.000000         0.0  0.126433  0.000000   8.0
# 447    0.000000     0.0   0.000000         8.0  0.000000  0.000000   8.0
# 448    0.000000    -1.0   0.000000         0.0  0.000000  0.126119   8.0
# 449    0.690515     0.0   0.000000         0.0  0.000000  0.180383   8.0
#
#      fitness
# 0      82.84
# 1      82.58
# 2      82.70
# 3      82.68
# 4      82.62
# ..       ...
# 445    81.44
# 446    83.67
# 447    83.22
# 448    84.24
# 449    84.13
#
# [450 rows x 14 columns]

# %% [markdown]
# # exp 1: fit linear regression and DT regressor to dataset

# %%
# init cv score lists
lr_scores = []
dt_scores = []

# %%
# fit linear regression  model to wide format data

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import export_text, plot_tree
import seaborn as sns
import matplotlib.pyplot as plt


X = df_long[ops]
y = df_long["fitness"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)
reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_)



regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=list(ops))
print(tree)

LR = LinearRegression()
lr_scores = cross_val_score(LR, X, y, cv=5)
DT = DecisionTreeRegressor(random_state=0)
dt_scores = cross_val_score(DT, X, y, cv=5)
long_format = []
long_format+=[["LR", s] for s in lr_scores]
long_format+=[["DT", s] for s in dt_scores]
df = pd.DataFrame(long_format, columns=["Method", "Score"])
sns.boxplot(data=df, x="Method", y="Score")
plt.show()
# Out:
# LR score:  -0.16203887534086814
# DT score:  0.2713775163494999
# |--- Brightness <= 0.28
# |   |--- Contrast <= 0.75
# |   |   |--- ShearY <= 0.12
# |   |   |   |--- Color <= 1.08
# |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |--- ShearY <= 0.02
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |   |   |   |--- Rotate <= 25.00
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.51
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.04]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.51
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.24]
# |   |   |   |   |   |   |   |--- Rotate >  25.00
# |   |   |   |   |   |   |   |   |--- TranslateY <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [81.88]
# |   |   |   |   |   |   |   |   |--- TranslateY >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |   |   |   |   |   |--- Color >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |   |   |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.55]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- Contrast <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |   |   |--- Contrast >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.40]
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |   |--- ShearY >  0.02
# |   |   |   |   |   |   |--- Solarize <= 0.73
# |   |   |   |   |   |   |   |--- Solarize <= 0.61
# |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.22]
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.35]
# |   |   |   |   |   |   |   |--- Solarize >  0.61
# |   |   |   |   |   |   |   |   |--- TranslateX <= 7.00
# |   |   |   |   |   |   |   |   |   |--- value: [82.81]
# |   |   |   |   |   |   |   |   |--- TranslateX >  7.00
# |   |   |   |   |   |   |   |   |   |--- value: [83.53]
# |   |   |   |   |   |   |--- Solarize >  0.73
# |   |   |   |   |   |   |   |--- value: [81.22]
# |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |--- ShearY <= 0.00
# |   |   |   |   |   |   |--- ShearX <= 0.21
# |   |   |   |   |   |   |   |--- Color <= 0.70
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.03
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.47]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.03
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Color >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.30]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Color >  0.70
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.17
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.24
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.24
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.61]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.17
# |   |   |   |   |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |   |   |--- ShearX >  0.21
# |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |--- value: [83.94]
# |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |--- value: [83.16]
# |   |   |   |   |   |--- ShearY >  0.00
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- TranslateY <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.44]
# |   |   |   |   |   |   |   |   |   |   |--- ShearY >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.54]
# |   |   |   |   |   |   |   |   |   |--- TranslateY >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- value: [82.36]
# |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.86]
# |   |   |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.75]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |--- Color >  1.08
# |   |   |   |   |--- HorizontalFlip <= 0.09
# |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |--- TranslateX <= 13.00
# |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |--- Rotate <= 11.00
# |   |   |   |   |   |   |   |   |   |--- Color <= 1.16
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.69]
# |   |   |   |   |   |   |   |   |   |--- Color >  1.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.58]
# |   |   |   |   |   |   |   |   |--- Rotate >  11.00
# |   |   |   |   |   |   |   |   |   |--- value: [82.43]
# |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 1.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.08]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  1.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- Color <= 1.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.52]
# |   |   |   |   |   |   |   |   |   |--- Color >  1.15
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- TranslateX >  13.00
# |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |--- value: [83.35]
# |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |--- value: [83.39]
# |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |--- value: [81.71]
# |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |--- HorizontalFlip >  0.09
# |   |   |   |   |   |--- value: [84.10]
# |   |   |--- ShearY >  0.12
# |   |   |   |--- TranslateY <= 1.50
# |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.08]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.14]
# |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.76]
# |   |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |--- ShearY >  0.16
# |   |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.57]
# |   |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |--- ShearX >  0.12
# |   |   |   |   |   |   |--- value: [83.33]
# |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |--- HorizontalFlip <= 0.49
# |   |   |   |   |   |   |--- ShearY <= 0.20
# |   |   |   |   |   |   |   |--- ShearX <= 0.02
# |   |   |   |   |   |   |   |   |--- Color <= 0.38
# |   |   |   |   |   |   |   |   |   |--- value: [83.74]
# |   |   |   |   |   |   |   |   |--- Color >  0.38
# |   |   |   |   |   |   |   |   |   |--- Rotate <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.41]
# |   |   |   |   |   |   |   |   |   |--- Rotate >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |   |   |   |   |--- ShearX >  0.02
# |   |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |--- ShearY >  0.20
# |   |   |   |   |   |   |   |--- Solarize <= 0.21
# |   |   |   |   |   |   |   |   |--- value: [82.97]
# |   |   |   |   |   |   |   |--- Solarize >  0.21
# |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |--- HorizontalFlip >  0.49
# |   |   |   |   |   |   |--- value: [82.21]
# |   |   |   |--- TranslateY >  1.50
# |   |   |   |   |--- value: [84.24]
# |   |--- Contrast >  0.75
# |   |   |--- ShearY <= 0.05
# |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |--- value: [83.78]
# |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |--- Contrast <= 1.07
# |   |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |   |   |--- Contrast >  1.07
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.04
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.03
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- Contrast <= 1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Contrast >  1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.03
# |   |   |   |   |   |   |   |   |   |--- value: [84.15]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.04
# |   |   |   |   |   |   |   |   |--- Contrast <= 1.47
# |   |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |   |--- Contrast >  1.47
# |   |   |   |   |   |   |   |   |   |--- Rotate <= 14.00
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |   |   |--- Rotate >  14.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |--- Contrast <= 1.72
# |   |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |   |   |--- TranslateX <= 11.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.84]
# |   |   |   |   |   |   |   |   |   |--- TranslateX >  11.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.91]
# |   |   |   |   |   |   |--- Contrast >  1.72
# |   |   |   |   |   |   |   |--- value: [83.49]
# |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |--- Color <= 0.66
# |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |--- Color >  0.66
# |   |   |   |   |   |   |   |--- value: [83.20]
# |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |--- value: [83.28]
# |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |--- ShearY >  0.05
# |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |--- Contrast <= 1.00
# |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |--- Contrast >  1.00
# |   |   |   |   |   |--- value: [82.42]
# |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |--- value: [82.84]
# |--- Brightness >  0.28
# |   |--- ShearY <= 0.15
# |   |   |--- ShearX <= 0.05
# |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |--- Solarize <= 0.60
# |   |   |   |   |   |--- VerticalFlip <= 0.43
# |   |   |   |   |   |   |--- Rotate <= 17.00
# |   |   |   |   |   |   |   |--- Rotate <= 6.50
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.20
# |   |   |   |   |   |   |   |   |   |--- value: [83.34]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.20
# |   |   |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |   |--- Rotate >  6.50
# |   |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |--- Rotate >  17.00
# |   |   |   |   |   |   |   |--- TranslateX <= 8.50
# |   |   |   |   |   |   |   |   |--- Brightness <= 1.00
# |   |   |   |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.16]
# |   |   |   |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |   |   |   |   |--- Brightness >  1.00
# |   |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |   |--- TranslateX >  8.50
# |   |   |   |   |   |   |   |   |--- value: [83.01]
# |   |   |   |   |   |--- VerticalFlip >  0.43
# |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |--- Solarize >  0.60
# |   |   |   |   |   |--- Solarize <= 0.89
# |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |--- value: [82.81]
# |   |   |   |   |   |--- Solarize >  0.89
# |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |--- ShearY >  0.06
# |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |--- value: [82.74]
# |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |--- value: [82.79]
# |   |   |--- ShearX >  0.05
# |   |   |   |--- Rotate <= 6.50
# |   |   |   |   |--- ShearX <= 0.16
# |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |--- value: [83.90]
# |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |--- VerticalFlip <= 0.43
# |   |   |   |   |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.41
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.61]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.53]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.41
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.12
# |   |   |   |   |   |   |   |   |   |--- value: [83.67]
# |   |   |   |   |   |   |   |--- ShearY >  0.06
# |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |--- VerticalFlip >  0.43
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.92
# |   |   |   |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.92
# |   |   |   |   |   |   |   |   |--- value: [83.46]
# |   |   |   |   |--- ShearX >  0.16
# |   |   |   |   |   |--- ShearX <= 0.20
# |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |--- ShearX >  0.20
# |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |--- Rotate >  6.50
# |   |   |   |   |--- Rotate <= 17.50
# |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |--- Rotate >  17.50
# |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |--- value: [83.26]
# |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |--- value: [83.10]
# |   |--- ShearY >  0.15
# |   |   |--- ShearY <= 0.18
# |   |   |   |--- Color <= 0.08
# |   |   |   |   |--- value: [83.25]
# |   |   |   |--- Color >  0.08
# |   |   |   |   |--- value: [84.13]
# |   |   |--- ShearY >  0.18
# |   |   |   |--- value: [83.14]

# %% [markdown]
# R-squared value for DT is 0.27 and -0.16 for LR.... Terrible

# %% [markdown]
# # exp 2: fit linear regression and DT regressor to dataset with L2 normalization

# %%
# normalize the data
from sklearn.preprocessing import normalize
X_train = normalize(X_train)
X_test = normalize(X_test)

reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_)
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=list(ops))
print(tree)

LR = LinearRegression()
lr_scores = cross_val_score(LR, X, y, cv=5)
DT = DecisionTreeRegressor(random_state=0)
dt_scores = cross_val_score(DT, X, y, cv=5)
long_format = []
long_format+=[["LR", s] for s in lr_scores]
long_format+=[["DT", s] for s in dt_scores]
df = pd.DataFrame(long_format, columns=["Method", "Score"])
sns.boxplot(data=df, x="Method", y="Score")
plt.show()
# Out:
# LR score:  -0.061633052508687
# DT score:  0.06762162618338186
# |--- Brightness <= 0.55
# |   |--- Contrast <= 0.55
# |   |   |--- Color <= 0.97
# |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |--- Rotate <= -0.29
# |   |   |   |   |   |--- Rotate <= -0.53
# |   |   |   |   |   |   |--- Color <= 0.56
# |   |   |   |   |   |   |   |--- value: [82.90]
# |   |   |   |   |   |   |--- Color >  0.56
# |   |   |   |   |   |   |   |--- value: [82.71]
# |   |   |   |   |   |--- Rotate >  -0.53
# |   |   |   |   |   |   |--- value: [84.24]
# |   |   |   |   |--- Rotate >  -0.29
# |   |   |   |   |   |--- ShearY <= 0.01
# |   |   |   |   |   |   |--- TranslateY <= 0.14
# |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |--- TranslateX <= 0.15
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.88
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.88
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.70]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.87]
# |   |   |   |   |   |   |   |   |--- TranslateX >  0.15
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.75]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.86]
# |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.11
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.90
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.44]
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.86
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.93]
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.11
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Color >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |--- TranslateY >  0.14
# |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |--- TranslateX <= 0.97
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.35
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.35
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.91]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.71]
# |   |   |   |   |   |   |   |   |--- TranslateX >  0.97
# |   |   |   |   |   |   |   |   |   |--- value: [81.83]
# |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.23
# |   |   |   |   |   |   |   |   |   |--- value: [83.47]
# |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.23
# |   |   |   |   |   |   |   |   |   |--- value: [83.94]
# |   |   |   |   |   |--- ShearY >  0.01
# |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |--- Rotate <= 0.50
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.82
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.33]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Solarize >  0.82
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.91
# |   |   |   |   |   |   |   |   |   |   |--- value: [81.22]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.91
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |--- Rotate >  0.50
# |   |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |--- ShearX <= 0.22
# |   |   |   |   |   |   |   |   |--- Color <= 0.96
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- ShearY >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Color >  0.96
# |   |   |   |   |   |   |   |   |   |--- value: [82.62]
# |   |   |   |   |   |   |   |--- ShearX >  0.22
# |   |   |   |   |   |   |   |   |--- value: [82.36]
# |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |--- ShearY <= 0.23
# |   |   |   |   |   |--- Rotate <= -0.36
# |   |   |   |   |   |   |--- Color <= 0.31
# |   |   |   |   |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |   |   |--- ShearY >  0.05
# |   |   |   |   |   |   |   |   |--- value: [82.13]
# |   |   |   |   |   |   |--- Color >  0.31
# |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |--- Rotate >  -0.36
# |   |   |   |   |   |   |--- ShearY <= 0.17
# |   |   |   |   |   |   |   |--- TranslateX <= 0.98
# |   |   |   |   |   |   |   |   |--- TranslateX <= 0.48
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |--- TranslateX >  0.48
# |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |   |--- TranslateX >  0.98
# |   |   |   |   |   |   |   |   |--- ShearY <= 0.02
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.46]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |   |   |--- ShearY >  0.02
# |   |   |   |   |   |   |   |   |   |--- value: [82.08]
# |   |   |   |   |   |   |--- ShearY >  0.17
# |   |   |   |   |   |   |   |--- Color <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [81.91]
# |   |   |   |   |   |   |   |--- Color >  0.50
# |   |   |   |   |   |   |   |   |--- value: [82.21]
# |   |   |   |   |--- ShearY >  0.23
# |   |   |   |   |   |--- HorizontalFlip <= 0.75
# |   |   |   |   |   |   |--- value: [83.41]
# |   |   |   |   |   |--- HorizontalFlip >  0.75
# |   |   |   |   |   |   |--- value: [83.74]
# |   |   |--- Color >  0.97
# |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |--- VerticalFlip <= 0.03
# |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |--- VerticalFlip >  0.03
# |   |   |   |   |   |--- value: [82.60]
# |   |   |   |--- ShearY >  0.05
# |   |   |   |   |--- Contrast <= 0.06
# |   |   |   |   |   |--- value: [84.10]
# |   |   |   |   |--- Contrast >  0.06
# |   |   |   |   |   |--- value: [83.58]
# |   |--- Contrast >  0.55
# |   |   |--- Contrast <= 0.84
# |   |   |   |--- Contrast <= 0.82
# |   |   |   |   |--- Color <= 0.27
# |   |   |   |   |   |--- Rotate <= -0.69
# |   |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |   |--- Rotate >  -0.69
# |   |   |   |   |   |   |--- Contrast <= 0.69
# |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |   |--- Contrast >  0.69
# |   |   |   |   |   |   |   |--- TranslateY <= 0.23
# |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |--- TranslateY >  0.23
# |   |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |   |--- Color >  0.27
# |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.14
# |   |   |   |   |   |   |   |--- value: [83.20]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.14
# |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |--- value: [83.63]
# |   |   |   |--- Contrast >  0.82
# |   |   |   |   |--- value: [84.15]
# |   |   |--- Contrast >  0.84
# |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |--- VerticalFlip <= 0.02
# |   |   |   |   |   |--- Solarize <= 0.04
# |   |   |   |   |   |   |--- ShearX <= 0.07
# |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |--- ShearX >  0.07
# |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |--- Solarize >  0.04
# |   |   |   |   |   |   |--- Contrast <= 0.96
# |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |   |   |--- Contrast >  0.96
# |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |--- VerticalFlip >  0.02
# |   |   |   |   |   |--- Contrast <= 0.86
# |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |--- Contrast >  0.86
# |   |   |   |   |   |   |--- Solarize <= 0.24
# |   |   |   |   |   |   |   |--- ShearX <= 0.03
# |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |--- ShearX >  0.03
# |   |   |   |   |   |   |   |   |--- value: [83.28]
# |   |   |   |   |   |   |--- Solarize >  0.24
# |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |--- ShearY >  0.05
# |   |   |   |   |--- value: [82.26]
# |--- Brightness >  0.55
# |   |--- Color <= 0.22
# |   |   |--- ShearX <= 0.04
# |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |--- Brightness <= 0.94
# |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |--- Brightness >  0.94
# |   |   |   |   |   |--- value: [82.74]
# |   |   |   |--- ShearY >  0.16
# |   |   |   |   |--- Color <= 0.11
# |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |--- Color >  0.11
# |   |   |   |   |   |--- value: [83.14]
# |   |   |--- ShearX >  0.04
# |   |   |   |--- Brightness <= 0.74
# |   |   |   |   |--- Solarize <= 0.41
# |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |--- Solarize >  0.41
# |   |   |   |   |   |--- value: [83.90]
# |   |   |   |--- Brightness >  0.74
# |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |--- ShearX <= 0.09
# |   |   |   |   |   |   |--- Solarize <= 0.33
# |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |--- Solarize >  0.33
# |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |--- ShearX >  0.09
# |   |   |   |   |   |   |--- value: [83.67]
# |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |--- value: [83.11]
# |   |--- Color >  0.22
# |   |   |--- ShearY <= 0.12
# |   |   |   |--- Color <= 0.41
# |   |   |   |   |--- value: [83.61]
# |   |   |   |--- Color >  0.41
# |   |   |   |   |--- value: [83.53]
# |   |   |--- ShearY >  0.12
# |   |   |   |--- value: [84.13]

# %% [markdown]
# Performance decreases when using l2 normalization

# %% [markdown]
# # exp 3: fit linear regression and DT regressor to dataset with categorical variables

# %%
# train with the categorical dataset
from sklearn.preprocessing import LabelEncoder
cols = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
X = df[cols]
y = df["test acc"]
for col in [f"aug{i}" for i in range(1, 4)]:
    le = LabelEncoder()
    le.fit(X[col])
    X[col] = le.transform(X[col])
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)

X_train = normalize(X_train)
X_test = normalize(X_test)

reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
# coeffs.append(reg.coef_)
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=cols)
print(tree)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_31038/237608164.py in <module>
#       2 from sklearn.preprocessing import LabelEncoder
#       3 cols = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
# ----> 4 X = df[cols]
#       5 y = df["test acc"]
#       6 for col in [f"aug{i}" for i in range(1, 4)]:
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['aug1', 'op1', 'aug2', 'op2', 'aug3', 'op3'], dtype='object')] are in the [columns]"

# %% [markdown]
# Considerably worse performance when using as categorical

# %% [markdown]
# # exp 4: fit linear regression and DT regressor to dataset with neutral values

# %%
# apply nuetral values to missing values, everything but solarize has value of 0.0 when not applied. 
neutral = {'Brightness':0.0,
 'Color':0.0,
 'Contrast':0.0,
 'HorizontalFlip':0.0,
 'Rotate':0.0,
 'Sharpness':0.0,
 'ShearX':0.0,
 'ShearY':0.0,
 'Solarize':1.0,
 'TranslateX':0.0,
 'TranslateY':0.0,
 'VerticalFlip':0.0
          }

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import export_text, plot_tree

df_long['Solarize'] = df_long['Solarize'].apply(lambda x: 1.0 if x == 0.0 else x)
X = df_long[ops]
y = df_long["fitness"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)
reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_) 
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=list(ops))
print(tree)

LR = LinearRegression()
lr_scores = cross_val_score(LR, X, y, cv=5)
DT = DecisionTreeRegressor(random_state=0)
dt_scores = cross_val_score(DT, X, y, cv=5)
long_format = []
long_format+=[["LR", s] for s in lr_scores]
long_format+=[["DT", s] for s in dt_scores]
df = pd.DataFrame(long_format, columns=["Method", "Score"])
sns.boxplot(data=df, x="Method", y="Score")
plt.show()
# Out:
# LR score:  -0.10152499866110598
# DT score:  0.04290551455583891
# |--- Solarize <= 0.61
# |   |--- ShearY <= 0.01
# |   |   |--- Rotate <= 14.00
# |   |   |   |--- Solarize <= 0.56
# |   |   |   |   |--- Solarize <= 0.41
# |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |--- Contrast <= 1.43
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.61
# |   |   |   |   |   |   |   |   |   |   |--- Brightness <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Brightness >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.61
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.46]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.69]
# |   |   |   |   |   |   |   |--- Contrast >  1.43
# |   |   |   |   |   |   |   |   |--- value: [84.15]
# |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |--- Color <= 0.80
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |   |   |--- Color >  0.80
# |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |   |--- value: [83.07]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.14
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.14
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.03]
# |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.87]
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.17]
# |   |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |   |--- value: [82.69]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |--- Solarize >  0.41
# |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |--- Solarize <= 0.50
# |   |   |   |   |   |   |   |--- Color <= 0.64
# |   |   |   |   |   |   |   |   |--- value: [82.38]
# |   |   |   |   |   |   |   |--- Color >  0.64
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |   |--- value: [82.68]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |   |--- value: [82.61]
# |   |   |   |   |   |   |--- Solarize >  0.50
# |   |   |   |   |   |   |   |--- value: [83.15]
# |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |--- Solarize <= 0.47
# |   |   |   |   |   |   |   |--- value: [82.04]
# |   |   |   |   |   |   |--- Solarize >  0.47
# |   |   |   |   |   |   |   |--- value: [82.22]
# |   |   |   |--- Solarize >  0.56
# |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |--- value: [83.60]
# |   |   |--- Rotate >  14.00
# |   |   |   |--- value: [81.88]
# |   |--- ShearY >  0.01
# |   |   |--- Color <= 0.22
# |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |--- TranslateY <= 1.00
# |   |   |   |   |   |--- Solarize <= 0.49
# |   |   |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.13]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 10.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.87]
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  10.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.86]
# |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |   |--- value: [82.33]
# |   |   |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |   |   |--- Solarize <= 0.33
# |   |   |   |   |   |   |   |   |--- value: [83.07]
# |   |   |   |   |   |   |   |--- Solarize >  0.33
# |   |   |   |   |   |   |   |   |--- value: [82.92]
# |   |   |   |   |   |--- Solarize >  0.49
# |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |--- value: [81.73]
# |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |--- TranslateY >  1.00
# |   |   |   |   |   |--- value: [82.07]
# |   |   |   |--- ShearY >  0.11
# |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |--- ShearY <= 0.14
# |   |   |   |   |   |   |   |   |--- value: [82.74]
# |   |   |   |   |   |   |   |--- ShearY >  0.14
# |   |   |   |   |   |   |   |   |--- value: [82.76]
# |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |--- ShearY >  0.16
# |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |--- value: [83.22]
# |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |--- value: [83.11]
# |   |   |--- Color >  0.22
# |   |   |   |--- ShearY <= 0.07
# |   |   |   |   |--- value: [81.51]
# |   |   |   |--- ShearY >  0.07
# |   |   |   |   |--- Solarize <= 0.44
# |   |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |   |--- value: [82.49]
# |   |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |   |--- value: [82.76]
# |   |   |   |   |--- Solarize >  0.44
# |   |   |   |   |   |--- ShearY <= 0.14
# |   |   |   |   |   |   |--- value: [82.05]
# |   |   |   |   |   |--- ShearY >  0.14
# |   |   |   |   |   |   |--- value: [82.57]
# |--- Solarize >  0.61
# |   |--- ShearY <= 0.12
# |   |   |--- Contrast <= 0.75
# |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |--- Color <= 0.40
# |   |   |   |   |   |--- TranslateX <= 7.00
# |   |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |   |--- value: [82.13]
# |   |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |--- TranslateX >  7.00
# |   |   |   |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |   |   |   |--- value: [82.93]
# |   |   |   |   |   |   |--- ShearY >  0.11
# |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |--- Color >  0.40
# |   |   |   |   |   |--- VerticalFlip <= 0.52
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |   |   |   |--- value: [82.71]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |--- VerticalFlip >  0.52
# |   |   |   |   |   |   |--- value: [82.90]
# |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |--- HorizontalFlip <= 0.39
# |   |   |   |   |   |--- HorizontalFlip <= 0.10
# |   |   |   |   |   |   |--- TranslateY <= 0.50
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.03
# |   |   |   |   |   |   |   |   |--- Color <= 0.44
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- Rotate <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Rotate >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Color >  0.44
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.95
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.95
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.03
# |   |   |   |   |   |   |   |   |--- Brightness <= 0.29
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Brightness >  0.29
# |   |   |   |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- Brightness <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Brightness >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |   |--- TranslateY >  0.50
# |   |   |   |   |   |   |   |--- ShearX <= 0.15
# |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.58]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 11.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.83]
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  11.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.63]
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.24]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- ShearX >  0.15
# |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.61
# |   |   |   |   |   |   |   |   |   |--- value: [83.47]
# |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.61
# |   |   |   |   |   |   |   |   |   |--- value: [83.94]
# |   |   |   |   |   |--- HorizontalFlip >  0.10
# |   |   |   |   |   |   |--- value: [84.10]
# |   |   |   |   |--- HorizontalFlip >  0.39
# |   |   |   |   |   |--- Solarize <= 0.98
# |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |--- Solarize >  0.98
# |   |   |   |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |   |   |   |--- Color <= 0.62
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |   |   |   |--- Color >  0.62
# |   |   |   |   |   |   |   |   |--- value: [82.55]
# |   |   |   |   |   |   |--- ShearY >  0.06
# |   |   |   |   |   |   |   |--- Color <= 0.28
# |   |   |   |   |   |   |   |   |--- Color <= 0.06
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.46]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |   |   |   |--- Color >  0.06
# |   |   |   |   |   |   |   |   |   |--- value: [81.91]
# |   |   |   |   |   |   |   |--- Color >  0.28
# |   |   |   |   |   |   |   |   |--- value: [82.62]
# |   |   |--- Contrast >  0.75
# |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |--- Contrast <= 1.18
# |   |   |   |   |   |--- TranslateY <= 1.00
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |   |   |   |   |--- value: [83.63]
# |   |   |   |   |   |--- TranslateY >  1.00
# |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |   |--- Contrast >  1.18
# |   |   |   |   |   |--- TranslateY <= 0.50
# |   |   |   |   |   |   |--- VerticalFlip <= 0.11
# |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |--- Rotate <= 14.00
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- Contrast <= 1.72
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |   |   |   |   |--- Contrast >  1.72
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |   |--- Rotate >  14.00
# |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- value: [83.20]
# |   |   |   |   |   |   |--- VerticalFlip >  0.11
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.92
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.82
# |   |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.82
# |   |   |   |   |   |   |   |   |   |--- value: [83.49]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.92
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |   |--- value: [83.28]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |--- TranslateY >  0.50
# |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |   |--- value: [83.40]
# |   |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |--- ShearY >  0.05
# |   |   |   |   |--- TranslateX <= 7.00
# |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |--- TranslateX >  7.00
# |   |   |   |   |   |--- value: [82.84]
# |   |--- ShearY >  0.12
# |   |   |--- TranslateX <= 3.00
# |   |   |   |--- HorizontalFlip <= 0.49
# |   |   |   |   |--- Color <= 0.30
# |   |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.23
# |   |   |   |   |   |   |   |--- Brightness <= 1.00
# |   |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |   |--- value: [84.24]
# |   |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |   |--- value: [84.13]
# |   |   |   |   |   |   |   |--- Brightness >  1.00
# |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.23
# |   |   |   |   |   |   |   |--- Brightness <= 0.29
# |   |   |   |   |   |   |   |   |--- value: [83.74]
# |   |   |   |   |   |   |   |--- Brightness >  0.29
# |   |   |   |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |   |--- Brightness <= 0.35
# |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |--- Brightness >  0.35
# |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |--- Color >  0.30
# |   |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |   |--- value: [82.14]
# |   |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |   |   |--- value: [83.41]
# |   |   |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |--- HorizontalFlip >  0.49
# |   |   |   |   |--- Brightness <= 0.66
# |   |   |   |   |   |--- value: [82.21]
# |   |   |   |   |--- Brightness >  0.66
# |   |   |   |   |   |--- value: [82.79]
# |   |   |--- TranslateX >  3.00
# |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |--- Color <= 0.87
# |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |--- value: [82.08]
# |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |--- TranslateX <= 10.00
# |   |   |   |   |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |--- TranslateX >  10.00
# |   |   |   |   |   |   |   |--- value: [82.42]
# |   |   |   |   |--- Color >  0.87
# |   |   |   |   |   |--- value: [82.97]
# |   |   |   |--- ShearX >  0.12
# |   |   |   |   |--- value: [83.33]

# %% [markdown]
# We do not see any improvement chanigng solarize to 1 instead of zero... this is expected.

# %%
df = pd.DataFrame(coeffs, columns = ops)

df

# %%
exp_dir = "/home/noah/ESSL/exps/iteration4/exp6_1"
coeffs = []
exps = glob.glob(os.path.join(exp_dir, "*/"))
# chromos = []
# for e in exps:
#     seed = e.split("/")[-2]
#     with open(os.path.join(e, "outcomes.json"), "r") as f:
#         results = json.load(f)
#         for fitness, chromo in zip(results["pop_vals"], results["chromos"]):
#             c = list(chain.from_iterable(chromo[1]))
#             c.append(seed)
#             c.append(fitness[1])
#             chromos.append(c)
# columns = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
# columns.append("seed")
# columns.append("test acc")
# columns

# df = pd.DataFrame(chromos, columns=columns)
# ops = set(list(df["aug1"]) + list(df["aug2"]) +  list(df["aug3"]))
# indexes = {op:i for i, op in enumerate(ops)}
# chromos_long = np.zeros([len(chromos), len(ops)+2])

# for i, c in enumerate(chromos):
#     for aug, intensity in zip(c[:-2][::2], c[:-2][1::2]):
#         chromos_long[i][indexes[aug]] = intensity
#         chromos_long[i][-2] = int(c[-2])
#         chromos_long[i][-1] = c[-1]

# columns_long = list(ops) + ["seed", "fitness"]
# df_long = pd.DataFrame(chromos_long, columns = columns_long)
# df_long
# ops
# df_long
e = exps[0]
with open(os.path.join(e, "outcomes.json"), "r") as f:
    results = json.load(f)
results
# Out:
# {'pop_vals': [[0, 82.84],
#   [0, 82.58],
#   [0, 82.7],
#   [0, 82.68],
#   [0, 82.62],
#   [0, 82.93],
#   [0, 82.44],
#   [0, 82.52],
#   [0, 82.91],
#   [0, 82.6],
#   [0, 82.55],
#   [0, 82.36],
#   [0, 82.93],
#   [0, 83.44],
#   [0, 83.4],
#   [1, 82.89],
#   [1, 83.03],
#   [1, 83.37],
#   [1, 83.11],
#   [1, 82.72],
#   [1, 83.22],
#   [1, 82.62],
#   [1, 81.93],
#   [1, 82.48],
#   [1, 83.36],
#   [1, 81.96],
#   [1, 82.5],
#   [1, 82.6],
#   [1, 83.44],
#   [1, 83.4],
#   [2, 83.11],
#   [2, 82.5],
#   [2, 81.96],
#   [2, 83.36],
#   [2, 82.12],
#   [2, 82.4],
#   [2, 82.84],
#   [2, 81.81],
#   [2, 82.71],
#   [2, 82.89],
#   [2, 83.35],
#   [2, 82.76],
#   [2, 82.42],
#   [2, 83.44],
#   [2, 83.4],
#   [3, 82.5],
#   [3, 83.36],
#   [3, 82.52],
#   [3, 82.13],
#   [3, 81.96],
#   [3, 82.84],
#   [3, 82.73],
#   [3, 82.9],
#   [3, 83.21],
#   [3, 82.56],
#   [3, 82.88],
#   [3, 82.93],
#   [3, 83.11],
#   [3, 83.44],
#   [3, 83.4],
#   [4, 82.64],
#   [4, 82.65],
#   [4, 82.19],
#   [4, 82.27],
#   [4, 82.9],
#   [4, 82.64],
#   [4, 83.1],
#   [4, 81.89],
#   [4, 82.67],
#   [4, 82.39],
#   [4, 82.4],
#   [4, 82.45],
#   [4, 82.92],
#   [4, 83.44],
#   [4, 83.4],
#   [5, 83.07],
#   [5, 82.13],
#   [5, 81.68],
#   [5, 83.11],
#   [5, 82.5],
#   [5, 81.67],
#   [5, 82.29],
#   [5, 82.55],
#   [5, 82.79],
#   [5, 82.62],
#   [5, 82.81],
#   [5, 83.1],
#   [5, 81.89],
#   [5, 83.44],
#   [5, 83.4],
#   [6, 83.07],
#   [6, 81.68],
#   [6, 82.72],
#   [6, 83.15],
#   [6, 81.93],
#   [6, 82.5],
#   [6, 83.1],
#   [6, 81.91],
#   [6, 81.73],
#   [6, 82.81],
#   [6, 82.52],
#   [6, 82.75],
#   [6, 82.55],
#   [6, 83.44],
#   [6, 83.4],
#   [7, 82.89],
#   [7, 83.1],
#   [7, 83.53],
#   [7, 82.66],
#   [7, 82.98],
#   [7, 83.07],
#   [7, 83.19],
#   [7, 82.8],
#   [7, 83.13],
#   [7, 82.8],
#   [7, 83.15],
#   [7, 82.8],
#   [7, 81.68],
#   [7, 83.44],
#   [7, 83.4],
#   [8, 83.17],
#   [8, 83.6],
#   [8, 82.12],
#   [8, 83.6],
#   [8, 82.57],
#   [8, 82.83],
#   [8, 82.92],
#   [8, 82.95],
#   [8, 82.81],
#   [8, 82.78],
#   [8, 82.87],
#   [8, 82.03],
#   [8, 82.79],
#   [8, 83.53],
#   [8, 83.44],
#   [9, 82.19],
#   [9, 82.42],
#   [9, 83.11],
#   [9, 83.44],
#   [9, 83.17],
#   [9, 82.76],
#   [9, 83.78],
#   [9, 81.51],
#   [9, 82.05],
#   [9, 82.85],
#   [9, 81.88],
#   [9, 82.14],
#   [9, 81.22],
#   [9, 83.6],
#   [9, 83.6]],
#  'min': [82.36, 81.93, 81.81, 81.96, 81.89, 81.67, 81.68, 81.68, 82.03, 81.22],
#  'max': [83.44, 83.44, 83.44, 83.44, 83.44, 83.44, 83.44, 83.53, 83.6, 83.78],
#  'avg': [82.76666666666667,
#   82.84200000000003,
#   82.73800000000003,
#   82.83133333333333,
#   82.66333333333334,
#   82.60333333333334,
#   82.61733333333333,
#   82.97466666666668,
#   82.934,
#   82.64799999999998],
#  'std': [0.30656520060307274,
#   0.4795025199754297,
#   0.5154958777688239,
#   0.4284058304405052,
#   0.4184203096815819,
#   0.5598769706118124,
#   0.5622984577208165,
#   0.4247174223959883,
#   0.46486987426697823,
#   0.7772618606387193],
#  'chromos': [[0, [['Rotate', 22], ['TranslateY', 2], ['TranslateX', 7]]],
#   [0,
#    [['ShearY', 0.12611886008119813],
#     ['Brightness', 1.3149367248429207],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [0,
#    [['VerticalFlip', 0.9819392547566425],
#     ['Color', 0.4690103551233184],
#     ['ShearX', 0.04153282252820434]]],
#   [0,
#    [['Sharpness', 0.6682215484232581],
#     ['Solarize', 0.42832124193876264],
#     ['Color', 0.953487788571864]]],
#   [0,
#    [['ShearX', 0.13672045760431148],
#     ['Color', 0.44366700132078707],
#     ['TranslateX', 10]]],
#   [0,
#    [['Color', 0.44366700132078707],
#     ['VerticalFlip', 0.1649378065796322],
#     ['ShearX', 0.10460432864702825]]],
#   [0,
#    [['ShearY', 0.11257289806960662],
#     ['Sharpness', 0.33936066048198305],
#     ['Contrast', 0.5241770747389685]]],
#   [0,
#    [['ShearX', 0.19855389601570533],
#     ['Color', 1.1492768005080465],
#     ['TranslateX', 12]]],
#   [0,
#    [['Contrast', 0.9686110141915404],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [0,
#    [['ShearY', 0.10984368049812793],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Rotate', -1]]],
#   [0,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [0,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['ShearX', 0.10460432864702825]]],
#   [0,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.2895879820755308]]],
#   [0,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [0, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [1,
#    [['Contrast', 0.9686110141915404],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [1,
#    [['ShearY', 0.11257289806960662],
#     ['TranslateX', 14],
#     ['Contrast', 0.5241770747389685]]],
#   [1,
#    [['ShearY', 0.12611886008119813],
#     ['Brightness', 1.3149367248429207],
#     ['ShearX', 0.10460432864702825]]],
#   [1,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [1,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Contrast', 0.5241770747389685]]],
#   [1,
#    [['ShearY', 0.11257289806960662],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.2895879820755308]]],
#   [1,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['ShearX', 0.04153282252820434]]],
#   [1,
#    [['VerticalFlip', 0.9819392547566425],
#     ['Color', 0.4690103551233184],
#     ['ShearX', 0.10460432864702825]]],
#   [1,
#    [['ShearY', 0.11257289806960662],
#     ['TranslateY', 2],
#     ['Contrast', 0.5241770747389685]]],
#   [1, [['Rotate', 22], ['Sharpness', 0.33936066048198305], ['TranslateX', 7]]],
#   [1,
#    [['VerticalFlip', 0.9819392547566425],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Rotate', -1]]],
#   [1,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [1,
#    [['Color', 0.803194689052403],
#     ['VerticalFlip', 0.05473728973982531],
#     ['ShearX', 0.10460432864702825]]],
#   [1,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [1, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [2,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [2,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [2,
#    [['VerticalFlip', 0.9819392547566425],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Rotate', -1]]],
#   [2, [['Rotate', 22], ['Sharpness', 0.33936066048198305], ['TranslateX', 7]]],
#   [2, [['ShearY', 0.11257289806960662], ['TranslateX', 14], ['Rotate', -1]]],
#   [2,
#    [['VerticalFlip', 0.9819392547566425],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Contrast', 0.5241770747389685]]],
#   [2,
#    [['Contrast', 0.9686110141915404],
#     ['TranslateX', 14],
#     ['ShearY', 0.10984368049812793]]],
#   [2,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [2,
#    [['Color', 0.803194689052403],
#     ['VerticalFlip', 0.05473728973982531],
#     ['Rotate', -1]]],
#   [2,
#    [['VerticalFlip', 0.9819392547566425],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['ShearX', 0.10460432864702825]]],
#   [2,
#    [['ShearY', 0.11257289806960662],
#     ['Sharpness', 0.33936066048198305],
#     ['ShearX', 0.04153282252820434]]],
#   [2,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.2895879820755308]]],
#   [2,
#    [['ShearY', 0.22243140504210498],
#     ['TranslateX', 13],
#     ['Contrast', 1.0230723563257822]]],
#   [2,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [2, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [3,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [3, [['Rotate', 22], ['Sharpness', 0.33936066048198305], ['TranslateX', 7]]],
#   [3,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [3,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [3,
#    [['Contrast', 0.9686110141915404],
#     ['Color', 0.44366700132078707],
#     ['ShearY', 0.10984368049812793]]],
#   [3,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [3,
#    [['Color', 0.803194689052403],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Rotate', -1]]],
#   [3,
#    [['VerticalFlip', 0.9819392547566425],
#     ['Color', 0.803194689052403],
#     ['Rotate', -1]]],
#   [3,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.2895879820755308]]],
#   [3,
#    [['Contrast', 0.9686110141915404],
#     ['Color', 0.44366700132078707],
#     ['ShearY', 0.10984368049812793]]],
#   [3,
#    [['VerticalFlip', 0.9819392547566425],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Solarize', 0.24018227543207848]]],
#   [3, [['ShearY', 0.10984368049812793], ['TranslateX', 14], ['Rotate', -1]]],
#   [3,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [3,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [3, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [4,
#    [['VerticalFlip', 0.9819392547566425],
#     ['Solarize', 0.24018227543207848],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [4,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Solarize', 0.24018227543207848]]],
#   [4,
#    [['Color', 0.803194689052403],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Rotate', -1]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.24018227543207848]]],
#   [4,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.3798763635328418]]],
#   [4,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [4, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['Color', 0.803194689052403],
#     ['Sharpness', 0.33936066048198305],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [5,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6262378297471899]]],
#   [5,
#    [['Color', 0.803194689052403],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [5,
#    [['ShearY', 0.10984368049812793],
#     ['HorizontalFlip', 0.014832446024553692],
#     ['Rotate', -1]]],
#   [5,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [5, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['Color', 0.803194689052403],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.12013497258178801],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [6,
#    [['ShearY', 0.02455863035320681],
#     ['TranslateX', 13],
#     ['Solarize', 0.6002572102328748]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6262378297471899]]],
#   [6,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.24018227543207848]]],
#   [6,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.6262378297471899]]],
#   [6,
#    [['Color', 0.803194689052403],
#     ['Sharpness', 0.33936066048198305],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [6,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [6, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [7,
#    [['VerticalFlip', 0.8599239496601867],
#     ['TranslateX', 14],
#     ['Solarize', 0.6355506690828847]]],
#   [7,
#    [['Color', 0.803194689052403],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [7,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.6262378297471899]]],
#   [7,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [7,
#    [['ShearY', 0.17204387401558568],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [7,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [7,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [7,
#    [['Sharpness', 0.33936066048198305],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [7,
#    [['ShearY', 0.02455863035320681],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [7,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6002572102328748]]],
#   [7,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [7,
#    [['ShearY', 0.02455863035320681],
#     ['TranslateX', 14],
#     ['Solarize', 0.6002572102328748]]],
#   [7,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [7,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [7, [['Rotate', 28], ['Contrast', 1.182348184804551], ['TranslateY', 1]]],
#   [8,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['HorizontalFlip', 0.603190610968185]]],
#   [8,
#    [['Sharpness', 0.33936066048198305],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6002572102328748]]],
#   [8, [['Rotate', 28], ['TranslateX', 14], ['TranslateY', 1]]],
#   [8,
#    [['VerticalFlip', 0.8599239496601867],
#     ['Contrast', 1.182348184804551],
#     ['Solarize', 0.6355506690828847]]],
#   [8,
#    [['ShearY', 0.17204387401558568],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6002572102328748]]],
#   [8,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['ShearY', 0.02455863035320681],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6002572102328748]]],
#   [8,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['ShearY', 0.17204387401558568],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['VerticalFlip', 0.9819392547566425],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['ShearY', 0.14420513152004155],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [8,
#    [['ShearY', 0.10984368049812793],
#     ['TranslateX', 14],
#     ['Solarize', 0.6262378297471899]]],
#   [8,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [9,
#    [['ShearY', 0.17204387401558568],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [9,
#    [['ShearY', 0.10984368049812793],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [9,
#    [['ShearY', 0.22387543031230311],
#     ['TranslateX', 13],
#     ['Solarize', 0.4142902287969425]]],
#   [9,
#    [['Solarize', 0.9697836444740757],
#     ['ShearX', 0.07151220076588884],
#     ['ShearY', 0.009524006761469294]]],
#   [9,
#    [['VerticalFlip', 0.9819392547566425],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [9,
#    [['ShearY', 0.14420513152004155],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.24018227543207848]]],
#   [9,
#    [['VerticalFlip', 0.9819392547566425],
#     ['Sharpness', 0.33936066048198305],
#     ['Solarize', 0.6002572102328748]]],
#   [9,
#    [['ShearY', 0.02455863035320681],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.24018227543207848]]],
#   [9,
#    [['ShearY', 0.10984368049812793],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6002572102328748]]],
#   [9,
#    [['ShearY', 0.17204387401558568],
#     ['TranslateX', 13],
#     ['Solarize', 0.24018227543207848]]],
#   [9, [['Rotate', 28], ['TranslateX', 14], ['Solarize', 0.6002572102328748]]],
#   [9,
#    [['ShearY', 0.17204387401558568],
#     ['Color', 0.44366700132078707],
#     ['TranslateY', 1]]],
#   [9,
#    [['ShearY', 0.05431719452011042],
#     ['Color', 0.572256448316621],
#     ['Solarize', 0.8306061789019725]]],
#   [9,
#    [['Sharpness', 0.33936066048198305],
#     ['Color', 0.44366700132078707],
#     ['Solarize', 0.6002572102328748]]],
#   [9,
#    [['VerticalFlip', 0.8599239496601867],
#     ['Contrast', 1.182348184804551],
#     ['Solarize', 0.6355506690828847]]]]}

# %%
from collections import defaultdict
from sklearn.model_selection import KFold

exps = ["/home/noah/ESSL/exps/iteration4/exp6_0", "/home/noah/ESSL/exps/iteration4/exp6_1"]
chromos = defaultdict(list)
for e_i in exps:
    exps_i = glob.glob(os.path.join(exp_dir, "*/"))
    for e in exps_i:
        seed = e.split("/")[-2]
        with open(os.path.join(e, "outcomes.json"), "r") as f:
            results = json.load(f)
            for fitness, chromo in zip(results["pop_vals"], results["chromos"]):
                c = list(chain.from_iterable(chromo[1]))
                c.append(e_i.split("/")[-1])
                c.append(seed)
                c.append(fitness[1])
                chromos[fitness[0]].append(c)
columns = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
columns.append("experiment")
columns.append("seed")
columns.append("test acc")
columns

# df = pd.DataFrame(chromos, columns=columns)
# df
total_importances = []
for gen, pop in chromos.items():
    chromos_long = np.zeros([len(pop), len(ops)+2])
    for i, c in enumerate(pop):
        for aug, intensity in zip(c[:-2][::2], c[:-2][1::2]):
            chromos_long[i][indexes[aug]] = intensity
            chromos_long[i][-2] = int(c[-2])
            chromos_long[i][-1] = c[-1]

    columns_long = list(ops) + ["seed", "fitness"]
    df_long = pd.DataFrame(chromos_long, columns = columns_long)
    X = df_long[ops].to_numpy()
    y = df_long["fitness"].to_numpy()

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)
#     reg = LinearRegression().fit(X_train, y_train)
#     print("LR score: ", reg.score(X_test, y_test))
#     # coeffs.append(reg.coef_)

#     regressor = DecisionTreeRegressor(random_state=0)
#     regressor.fit(X_train, y_train)
#     print("DT score: ", regressor.score(X_test, y_test))
#     print("depth: ", regressor.get_depth())
#     importance = regressor.feature_importances_
#     print("feature importance: ", importance)
    
    # run kfold again with and get importances for each fold
    kf = KFold(n_splits=5)
    importances = []
    dt_scores = []
    for train, test in kf.split(X):
        X_train, X_test, y_train, y_test = X[train], X[test], y[train], y[test]
        DT = DecisionTreeRegressor(random_state=0)
        DT.fit(X_train, y_train)
        dt_scores.append(DT.score(X_test, y_test))
        for imp, op in zip(regressor.feature_importances_, ops):
            importances.append([imp, op])
        total_importances+=importances
    importance_df = pd.DataFrame(importances, columns = ["importance", "ops"])
    LR = LinearRegression()
    lr_scores = cross_val_score(LR, X, y, cv=5)
    long_format = []
    long_format+=[["LR", s] for s in lr_scores]
    long_format+=[["DT", s] for s in dt_scores]
    df = pd.DataFrame(long_format, columns=["Method", "Score"])
    sns.boxplot(data=df, x="Method", y="Score")
    plt.suptitle(f"CV on Generation {gen}")
    plt.show()
    plt.clf()
    
    sns.barplot(data = importance_df, x = "ops", y = "importance")
    plt.xticks(rotation=90)
    plt.suptitle(f"DT Feature Importance, Gen {gen}")
    plt.show()
    plt.clf()
total_importance_df = pd.DataFrame(total_importances, columns = ["importance", "ops"])
sns.barplot(data = total_importance_df, x = "ops", y = "importance")
plt.xticks(rotation=90)
plt.suptitle(f"DT Feature Importance, All Gens")
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_31038/1448088982.py in <module>
#      80     plt.clf()
#      81 total_importance_df = pd.DataFrame(total_importances, columns = ["importance", "ops"])
# ---> 82 sns.barplot(data = total_importance_df, x = "ops", y = "importance", errorbar=('ci', 95))
#      83 plt.xticks(rotation=90)
#      84 plt.suptitle(f"DT Feature Importance, All Gens")
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3188         ax = plt.gca()
#    3189
# -> 3190     plotter.plot(ax, kwargs)
#    3191     return ax
#    3192
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1637     def plot(self, ax, bar_kws):
#    1638         """Make the plot."""
# -> 1639         self.draw_bars(ax, bar_kws)
#    1640         self.annotate_axes(ax)
#    1641         if self.orient == "h":
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1603             # Draw the bars
#    1604             barfunc(barpos, self.statistic, self.width,
# -> 1605                     color=self.colors, align="center", **kws)
#    1606
#    1607             # Draw the confidence intervals
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2401                 hatch=htch,
#    2402                 )
# -> 2403             r.update(kwargs)
#    2404             r.get_path()._interpolation_steps = 100
#    2405             if orientation == 'vertical':
#
# ~/.conda/envs/essl/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'errorbar'
