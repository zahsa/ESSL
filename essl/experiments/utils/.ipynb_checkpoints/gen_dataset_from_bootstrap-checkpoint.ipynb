# %%
import json
import pandas as pd
import glob
import os
from itertools import chain
import numpy as np

# %%
exp_dir = "/home/noah/ESSL/exps/iteration4/exp6_1"
coeffs = []
exps = glob.glob(os.path.join(exp_dir, "*/"))
chromos = []
for e in exps:
    seed = e.split("/")[-2]
    with open(os.path.join(e, "outcomes.json"), "r") as f:
        results = json.load(f)
        for fitness, chromo in zip(results["pop_vals"], results["chromos"]):
            c = list(chain.from_iterable(chromo[1]))
            c.append(seed)
            c.append(fitness[1])
            chromos.append(c)
columns = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
columns.append("seed")
columns.append("test acc")
columns

df = pd.DataFrame(chromos, columns=columns)
ops = set(list(df["aug1"]) + list(df["aug2"]) +  list(df["aug3"]))
indexes = {op:i for i, op in enumerate(ops)}
chromos_long = np.zeros([len(chromos), len(ops)+2])

for i, c in enumerate(chromos):
    for aug, intensity in zip(c[:-2][::2], c[:-2][1::2]):
        chromos_long[i][indexes[aug]] = intensity
        chromos_long[i][-2] = int(c[-2])
        chromos_long[i][-1] = c[-1]

columns_long = list(ops) + ["seed", "fitness"]
df_long = pd.DataFrame(chromos_long, columns = columns_long)
df_long
ops
df_long
# Out:
#        ShearY  VerticalFlip  Sharpness  HorizontalFlip  Solarize  TranslateX  \
# 0    0.000000      0.000000   0.000000        0.000000  0.000000         7.0
# 1    0.126119      0.000000   0.000000        0.603191  0.000000         0.0
# 2    0.000000      0.981939   0.000000        0.000000  0.000000         0.0
# 3    0.000000      0.000000   0.668222        0.000000  0.428321         0.0
# 4    0.000000      0.000000   0.000000        0.000000  0.000000        10.0
# ..        ...           ...        ...             ...       ...         ...
# 445  0.000000      0.850476   0.000000        0.000000  0.000000         0.0
# 446  0.000000      0.000000   0.000000        0.000000  0.813661         0.0
# 447  0.000000      0.850476   0.000000        0.000000  0.000000         8.0
# 448  0.126119      0.000000   0.000000        0.000000  0.000000         0.0
# 449  0.180383      0.000000   0.000000        0.000000  0.000000         0.0
#
#      Brightness  Rotate  Contrast    ShearX  TranslateY     Color  seed  \
# 0      0.000000    22.0       0.0  0.000000         2.0  0.000000   7.0
# 1      1.314937     0.0       0.0  0.000000         0.0  0.000000   7.0
# 2      0.000000     0.0       0.0  0.041533         0.0  0.469010   7.0
# 3      0.000000     0.0       0.0  0.000000         0.0  0.953488   7.0
# 4      0.000000     0.0       0.0  0.136720         0.0  0.443667   7.0
# ..          ...     ...       ...       ...         ...       ...   ...
# 445    0.000000     0.0       0.0  0.104604         0.0  0.594466   8.0
# 446    0.918928     0.0       0.0  0.126433         0.0  0.000000   8.0
# 447    0.000000     0.0       0.0  0.000000         3.0  0.000000   8.0
# 448    0.000000    -1.0       0.0  0.000000         2.0  0.000000   8.0
# 449    0.690515     0.0       0.0  0.000000         0.0  0.161926   8.0
#
#      fitness
# 0      82.84
# 1      82.58
# 2      82.70
# 3      82.68
# 4      82.62
# ..       ...
# 445    81.44
# 446    83.67
# 447    83.22
# 448    84.24
# 449    84.13
#
# [450 rows x 14 columns]

# %% [markdown]
# # exp 1: fit linear regression and DT regressor to dataset

# %%
# fit linear regression  model to wide format data

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import export_text, plot_tree

X = df_long[ops]
y = df_long["fitness"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)
reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_)
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=list(ops))
print(tree)
# Out:
# LR score:  -0.16203887534086814
# DT score:  0.16537893087107924
# |--- Brightness <= 0.28
# |   |--- Contrast <= 0.75
# |   |   |--- ShearY <= 0.12
# |   |   |   |--- Color <= 1.08
# |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |--- ShearY <= 0.02
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |   |   |   |--- Rotate <= 25.00
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.51
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.04]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.51
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.24]
# |   |   |   |   |   |   |   |--- Rotate >  25.00
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.30
# |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.30
# |   |   |   |   |   |   |   |   |   |--- value: [81.88]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |   |   |   |   |   |--- Color >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.55]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- Contrast <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |   |   |--- Contrast >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.40]
# |   |   |   |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |   |--- ShearY >  0.02
# |   |   |   |   |   |   |--- Color <= 0.51
# |   |   |   |   |   |   |   |--- Solarize <= 0.61
# |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.22]
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.35]
# |   |   |   |   |   |   |   |--- Solarize >  0.61
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- value: [83.53]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.81]
# |   |   |   |   |   |   |--- Color >  0.51
# |   |   |   |   |   |   |   |--- value: [81.22]
# |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |--- ShearY <= 0.00
# |   |   |   |   |   |   |--- ShearX <= 0.21
# |   |   |   |   |   |   |   |--- Color <= 0.70
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.03
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.47]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.03
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Color >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.30]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Color >  0.70
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.17
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |   |--- Color >  0.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.61]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.17
# |   |   |   |   |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |   |   |--- ShearX >  0.21
# |   |   |   |   |   |   |   |--- ShearX <= 0.22
# |   |   |   |   |   |   |   |   |--- value: [83.94]
# |   |   |   |   |   |   |   |--- ShearX >  0.22
# |   |   |   |   |   |   |   |   |--- value: [83.16]
# |   |   |   |   |   |--- ShearY >  0.00
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- TranslateY <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.44]
# |   |   |   |   |   |   |   |   |   |   |--- ShearY >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.54]
# |   |   |   |   |   |   |   |   |   |--- TranslateY >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- value: [82.36]
# |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.86]
# |   |   |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.75]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |--- Color >  1.08
# |   |   |   |   |--- HorizontalFlip <= 0.09
# |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |--- TranslateX <= 13.00
# |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |--- Rotate <= 11.00
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.69]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.58]
# |   |   |   |   |   |   |   |   |--- Rotate >  11.00
# |   |   |   |   |   |   |   |   |   |--- value: [82.43]
# |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 1.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.08]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  1.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.52]
# |   |   |   |   |   |   |--- TranslateX >  13.00
# |   |   |   |   |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |   |   |   |   |--- value: [83.39]
# |   |   |   |   |   |   |   |--- ShearY >  0.05
# |   |   |   |   |   |   |   |   |--- value: [83.35]
# |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |--- value: [81.71]
# |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |--- HorizontalFlip >  0.09
# |   |   |   |   |   |--- value: [84.10]
# |   |   |--- ShearY >  0.12
# |   |   |   |--- TranslateY <= 1.50
# |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |--- ShearY <= 0.15
# |   |   |   |   |   |   |   |   |   |--- value: [82.08]
# |   |   |   |   |   |   |   |   |--- ShearY >  0.15
# |   |   |   |   |   |   |   |   |   |--- value: [82.14]
# |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.76]
# |   |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |--- ShearY >  0.16
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.42
# |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.42
# |   |   |   |   |   |   |   |   |   |--- value: [82.57]
# |   |   |   |   |   |--- ShearX >  0.12
# |   |   |   |   |   |   |--- value: [83.33]
# |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |--- HorizontalFlip <= 0.49
# |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |--- ShearX <= 0.02
# |   |   |   |   |   |   |   |   |--- Color <= 0.38
# |   |   |   |   |   |   |   |   |   |--- value: [83.74]
# |   |   |   |   |   |   |   |   |--- Color >  0.38
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.41]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |   |   |   |   |--- ShearX >  0.02
# |   |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |--- ShearY <= 0.22
# |   |   |   |   |   |   |   |   |--- value: [82.97]
# |   |   |   |   |   |   |   |--- ShearY >  0.22
# |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |--- HorizontalFlip >  0.49
# |   |   |   |   |   |   |--- value: [82.21]
# |   |   |   |--- TranslateY >  1.50
# |   |   |   |   |--- value: [84.24]
# |   |--- Contrast >  0.75
# |   |   |--- ShearY <= 0.05
# |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |--- value: [83.78]
# |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |--- Contrast <= 1.07
# |   |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |   |   |--- Contrast >  1.07
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.04
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.03
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- Contrast <= 1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Contrast >  1.43
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.03
# |   |   |   |   |   |   |   |   |   |--- value: [84.15]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.04
# |   |   |   |   |   |   |   |   |--- Contrast <= 1.47
# |   |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |   |--- Contrast >  1.47
# |   |   |   |   |   |   |   |   |   |--- Rotate <= 14.00
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |   |   |   |--- Rotate >  14.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |--- Contrast <= 1.72
# |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.12
# |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |   |--- Solarize >  0.12
# |   |   |   |   |   |   |   |   |   |--- Contrast <= 1.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.91]
# |   |   |   |   |   |   |   |   |   |--- Contrast >  1.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.84]
# |   |   |   |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |--- Contrast >  1.72
# |   |   |   |   |   |   |   |--- value: [83.49]
# |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |--- Color <= 0.66
# |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |--- Color >  0.66
# |   |   |   |   |   |   |   |--- value: [83.20]
# |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |--- value: [83.28]
# |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |--- ShearY >  0.05
# |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |--- Contrast <= 1.00
# |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |--- Contrast >  1.00
# |   |   |   |   |   |--- value: [82.42]
# |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |--- value: [82.84]
# |--- Brightness >  0.28
# |   |--- ShearY <= 0.15
# |   |   |--- ShearX <= 0.05
# |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |--- Solarize <= 0.60
# |   |   |   |   |   |--- VerticalFlip <= 0.43
# |   |   |   |   |   |   |--- Rotate <= 17.00
# |   |   |   |   |   |   |   |--- Brightness <= 0.64
# |   |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |   |--- Brightness >  0.64
# |   |   |   |   |   |   |   |   |--- Brightness <= 0.80
# |   |   |   |   |   |   |   |   |   |--- value: [83.34]
# |   |   |   |   |   |   |   |   |--- Brightness >  0.80
# |   |   |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |--- Rotate >  17.00
# |   |   |   |   |   |   |   |--- Rotate <= 21.50
# |   |   |   |   |   |   |   |   |--- value: [83.01]
# |   |   |   |   |   |   |   |--- Rotate >  21.50
# |   |   |   |   |   |   |   |   |--- Brightness <= 1.00
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.25
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |   |   |   |   |   |--- Color >  0.25
# |   |   |   |   |   |   |   |   |   |   |--- Brightness <= 0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.16]
# |   |   |   |   |   |   |   |   |   |   |--- Brightness >  0.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.16]
# |   |   |   |   |   |   |   |   |--- Brightness >  1.00
# |   |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |--- VerticalFlip >  0.43
# |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |--- Solarize >  0.60
# |   |   |   |   |   |--- Brightness <= 0.80
# |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |   |   |--- Brightness >  0.80
# |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |--- value: [82.81]
# |   |   |   |--- ShearY >  0.06
# |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |--- value: [82.74]
# |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |--- value: [82.79]
# |   |   |--- ShearX >  0.05
# |   |   |   |--- Rotate <= 6.50
# |   |   |   |   |--- ShearX <= 0.16
# |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |--- value: [83.90]
# |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |--- VerticalFlip <= 0.43
# |   |   |   |   |   |   |   |--- Brightness <= 1.12
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |   |   |   |   |   |--- Brightness <= 0.80
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.61]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.53]
# |   |   |   |   |   |   |   |   |   |--- Brightness >  0.80
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.12
# |   |   |   |   |   |   |   |   |   |--- value: [83.67]
# |   |   |   |   |   |   |   |--- Brightness >  1.12
# |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |--- VerticalFlip >  0.43
# |   |   |   |   |   |   |   |--- Brightness <= 0.75
# |   |   |   |   |   |   |   |   |--- value: [83.46]
# |   |   |   |   |   |   |   |--- Brightness >  0.75
# |   |   |   |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |--- ShearX >  0.16
# |   |   |   |   |   |--- ShearX <= 0.20
# |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |--- ShearX >  0.20
# |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |--- Rotate >  6.50
# |   |   |   |   |--- Rotate <= 17.50
# |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |--- Rotate >  17.50
# |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |--- value: [83.26]
# |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |--- value: [83.10]
# |   |--- ShearY >  0.15
# |   |   |--- ShearY <= 0.18
# |   |   |   |--- HorizontalFlip <= 0.23
# |   |   |   |   |--- value: [84.13]
# |   |   |   |--- HorizontalFlip >  0.23
# |   |   |   |   |--- value: [83.25]
# |   |   |--- ShearY >  0.18
# |   |   |   |--- value: [83.14]

# %% [markdown]
# R-squared value for DT is 0.27 and -0.16 for LR.... Terrible

# %% [markdown]
# # exp 2: fit linear regression and DT regressor to dataset with L2 normalization

# %%
# normalize the data
from sklearn.preprocessing import normalize
X_train = normalize(X_train)
X_test = normalize(X_test)

reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_)
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=list(ops))
print(tree)
# Out:
# LR score:  -0.061633052508687
# DT score:  0.13911920524795485
# |--- Brightness <= 0.55
# |   |--- Contrast <= 0.55
# |   |   |--- Color <= 0.97
# |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |--- Rotate <= -0.29
# |   |   |   |   |   |--- Rotate <= -0.53
# |   |   |   |   |   |   |--- VerticalFlip <= 0.33
# |   |   |   |   |   |   |   |--- value: [82.71]
# |   |   |   |   |   |   |--- VerticalFlip >  0.33
# |   |   |   |   |   |   |   |--- value: [82.90]
# |   |   |   |   |   |--- Rotate >  -0.53
# |   |   |   |   |   |   |--- value: [84.24]
# |   |   |   |   |--- Rotate >  -0.29
# |   |   |   |   |   |--- ShearY <= 0.01
# |   |   |   |   |   |   |--- TranslateY <= 0.14
# |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |--- TranslateX <= 0.15
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.88
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.88
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.70]
# |   |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.87]
# |   |   |   |   |   |   |   |   |--- TranslateX >  0.15
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.03
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- TranslateX >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.75]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.03
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.86]
# |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.11
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.90
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.93]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.44]
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.11
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.97
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Color >  0.97
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |--- TranslateY >  0.14
# |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |--- TranslateX <= 0.97
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.35
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.35
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.71]
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.91]
# |   |   |   |   |   |   |   |   |--- TranslateX >  0.97
# |   |   |   |   |   |   |   |   |   |--- value: [81.83]
# |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.23
# |   |   |   |   |   |   |   |   |   |--- value: [83.47]
# |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.23
# |   |   |   |   |   |   |   |   |   |--- value: [83.94]
# |   |   |   |   |   |--- ShearY >  0.01
# |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |--- Rotate <= 0.50
# |   |   |   |   |   |   |   |   |--- Solarize <= 0.82
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- Rotate <= -0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |   |   |   |--- Rotate >  -0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.33]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Solarize >  0.82
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [81.22]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |--- Rotate >  0.50
# |   |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |--- ShearX <= 0.22
# |   |   |   |   |   |   |   |   |--- Color <= 0.96
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- ShearY >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Color >  0.96
# |   |   |   |   |   |   |   |   |   |--- value: [82.62]
# |   |   |   |   |   |   |   |--- ShearX >  0.22
# |   |   |   |   |   |   |   |   |--- value: [82.36]
# |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |--- ShearY <= 0.23
# |   |   |   |   |   |--- Rotate <= -0.36
# |   |   |   |   |   |   |--- Color <= 0.31
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.35
# |   |   |   |   |   |   |   |   |--- value: [82.13]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.35
# |   |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |   |--- Color >  0.31
# |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |--- Rotate >  -0.36
# |   |   |   |   |   |   |--- ShearY <= 0.17
# |   |   |   |   |   |   |   |--- TranslateX <= 0.98
# |   |   |   |   |   |   |   |   |--- TranslateX <= 0.48
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |--- TranslateX >  0.48
# |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |   |--- TranslateX >  0.98
# |   |   |   |   |   |   |   |   |--- ShearY <= 0.02
# |   |   |   |   |   |   |   |   |   |--- TranslateX <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |   |   |   |--- TranslateX >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.46]
# |   |   |   |   |   |   |   |   |--- ShearY >  0.02
# |   |   |   |   |   |   |   |   |   |--- value: [82.08]
# |   |   |   |   |   |   |--- ShearY >  0.17
# |   |   |   |   |   |   |   |--- Color <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [81.91]
# |   |   |   |   |   |   |   |--- Color >  0.50
# |   |   |   |   |   |   |   |   |--- value: [82.21]
# |   |   |   |   |--- ShearY >  0.23
# |   |   |   |   |   |--- ShearY <= 0.29
# |   |   |   |   |   |   |--- value: [83.41]
# |   |   |   |   |   |--- ShearY >  0.29
# |   |   |   |   |   |   |--- value: [83.74]
# |   |   |--- Color >  0.97
# |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |--- Solarize <= 0.03
# |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |--- Solarize >  0.03
# |   |   |   |   |   |--- value: [82.66]
# |   |   |   |--- ShearY >  0.05
# |   |   |   |   |--- ShearY <= 0.10
# |   |   |   |   |   |--- value: [83.58]
# |   |   |   |   |--- ShearY >  0.10
# |   |   |   |   |   |--- value: [84.10]
# |   |--- Contrast >  0.55
# |   |   |--- Contrast <= 0.84
# |   |   |   |--- Contrast <= 0.82
# |   |   |   |   |--- Color <= 0.27
# |   |   |   |   |   |--- Rotate <= -0.69
# |   |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |   |--- Rotate >  -0.69
# |   |   |   |   |   |   |--- Contrast <= 0.69
# |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |   |--- Contrast >  0.69
# |   |   |   |   |   |   |   |--- Sharpness <= 0.20
# |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |--- Sharpness >  0.20
# |   |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |   |--- Color >  0.27
# |   |   |   |   |   |--- Color <= 0.61
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.14
# |   |   |   |   |   |   |   |--- value: [83.20]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.14
# |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |--- Color >  0.61
# |   |   |   |   |   |   |--- value: [83.63]
# |   |   |   |--- Contrast >  0.82
# |   |   |   |   |--- value: [84.15]
# |   |   |--- Contrast >  0.84
# |   |   |   |--- Color <= 0.25
# |   |   |   |   |--- VerticalFlip <= 0.02
# |   |   |   |   |   |--- Solarize <= 0.04
# |   |   |   |   |   |   |--- Solarize <= 0.02
# |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |--- Solarize >  0.02
# |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |--- Solarize >  0.04
# |   |   |   |   |   |   |--- Solarize <= 0.13
# |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |--- Solarize >  0.13
# |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |--- VerticalFlip >  0.02
# |   |   |   |   |   |--- Contrast <= 0.86
# |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |--- Contrast >  0.86
# |   |   |   |   |   |   |--- VerticalFlip <= 0.04
# |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |--- VerticalFlip >  0.04
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.27
# |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.27
# |   |   |   |   |   |   |   |   |--- value: [83.28]
# |   |   |   |--- Color >  0.25
# |   |   |   |   |--- value: [82.26]
# |--- Brightness >  0.55
# |   |--- Color <= 0.22
# |   |   |--- ShearX <= 0.04
# |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |--- Solarize <= 0.09
# |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |--- Solarize >  0.09
# |   |   |   |   |   |--- value: [82.74]
# |   |   |   |--- ShearY >  0.16
# |   |   |   |   |--- ShearY <= 0.24
# |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |--- ShearY >  0.24
# |   |   |   |   |   |--- value: [83.14]
# |   |   |--- ShearX >  0.04
# |   |   |   |--- Brightness <= 0.74
# |   |   |   |   |--- ShearX <= 0.09
# |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |--- ShearX >  0.09
# |   |   |   |   |   |--- value: [83.90]
# |   |   |   |--- Brightness >  0.74
# |   |   |   |   |--- Brightness <= 0.74
# |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |--- Brightness >  0.74
# |   |   |   |   |   |--- ShearX <= 0.09
# |   |   |   |   |   |   |--- Brightness <= 0.87
# |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |--- Brightness >  0.87
# |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |--- ShearX >  0.09
# |   |   |   |   |   |   |--- value: [83.67]
# |   |--- Color >  0.22
# |   |   |--- ShearY <= 0.12
# |   |   |   |--- Color <= 0.41
# |   |   |   |   |--- value: [83.61]
# |   |   |   |--- Color >  0.41
# |   |   |   |   |--- value: [83.53]
# |   |   |--- ShearY >  0.12
# |   |   |   |--- value: [84.13]

# %% [markdown]
# Performance decreases when using l2 normalization

# %% [markdown]
# # exp 3: fit linear regression and DT regressor to dataset with categorical variables

# %%
# train with the categorical dataset
from sklearn.preprocessing import LabelEncoder
cols = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
X = df[cols]
y = df["test acc"]
for col in [f"aug{i}" for i in range(1, 4)]:
    le = LabelEncoder()
    le.fit(X[col])
    X[col] = le.transform(X[col])
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)

X_train = normalize(X_train)
X_test = normalize(X_test)

reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_)
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=cols)
print(tree)
df
# Out:
# LR score:  0.08612154148451179
# DT score:  0.02720782036457059
# |--- aug1 <= 0.99
# |   |--- op1 <= 0.09
# |   |   |--- op3 <= -0.08
# |   |   |   |--- op3 <= -0.08
# |   |   |   |   |--- op1 <= 0.04
# |   |   |   |   |   |--- value: [82.13]
# |   |   |   |   |--- op1 >  0.04
# |   |   |   |   |   |--- value: [82.71]
# |   |   |   |--- op3 >  -0.08
# |   |   |   |   |--- value: [84.24]
# |   |   |--- op3 >  -0.08
# |   |   |   |--- op1 <= 0.02
# |   |   |   |   |--- aug3 <= 0.03
# |   |   |   |   |   |--- aug2 <= 0.52
# |   |   |   |   |   |   |--- op2 <= 0.51
# |   |   |   |   |   |   |   |--- value: [84.15]
# |   |   |   |   |   |   |--- op2 >  0.51
# |   |   |   |   |   |   |   |--- op2 <= 0.80
# |   |   |   |   |   |   |   |   |--- value: [83.35]
# |   |   |   |   |   |   |   |--- op2 >  0.80
# |   |   |   |   |   |   |   |   |--- value: [83.39]
# |   |   |   |   |   |--- aug2 >  0.52
# |   |   |   |   |   |   |--- op2 <= 0.18
# |   |   |   |   |   |   |   |--- op3 <= 0.10
# |   |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |   |   |   |--- op3 >  0.10
# |   |   |   |   |   |   |   |   |--- aug1 <= 0.60
# |   |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |   |   |--- aug1 >  0.60
# |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |--- op2 >  0.18
# |   |   |   |   |   |   |   |--- aug1 <= 0.49
# |   |   |   |   |   |   |   |   |--- aug2 <= 0.87
# |   |   |   |   |   |   |   |   |   |--- op2 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |   |--- op2 >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- aug2 >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.22]
# |   |   |   |   |   |   |   |   |--- aug2 >  0.87
# |   |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |   |--- aug1 >  0.49
# |   |   |   |   |   |   |   |   |--- op2 <= 0.38
# |   |   |   |   |   |   |   |   |   |--- value: [83.46]
# |   |   |   |   |   |   |   |   |--- op2 >  0.38
# |   |   |   |   |   |   |   |   |   |--- value: [83.19]
# |   |   |   |   |--- aug3 >  0.03
# |   |   |   |   |   |--- op3 <= 0.03
# |   |   |   |   |   |   |--- op1 <= 0.02
# |   |   |   |   |   |   |   |--- aug3 <= 0.32
# |   |   |   |   |   |   |   |   |--- op3 <= -0.02
# |   |   |   |   |   |   |   |   |   |--- op1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.93]
# |   |   |   |   |   |   |   |   |   |--- op1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |   |   |   |--- aug2 >  0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |   |--- op3 >  -0.02
# |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.53]
# |   |   |   |   |   |   |   |   |   |--- aug2 >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- op3 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- op3 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- aug3 >  0.32
# |   |   |   |   |   |   |   |   |--- op1 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.51]
# |   |   |   |   |   |   |   |   |   |   |--- aug2 >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.73]
# |   |   |   |   |   |   |   |   |--- op1 >  0.01
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.35]
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- op1 >  0.02
# |   |   |   |   |   |   |   |--- aug3 <= 0.55
# |   |   |   |   |   |   |   |   |--- value: [83.54]
# |   |   |   |   |   |   |   |--- aug3 >  0.55
# |   |   |   |   |   |   |   |   |--- value: [82.62]
# |   |   |   |   |   |--- op3 >  0.03
# |   |   |   |   |   |   |--- aug1 <= 0.31
# |   |   |   |   |   |   |   |--- value: [83.08]
# |   |   |   |   |   |   |--- aug1 >  0.31
# |   |   |   |   |   |   |   |--- op3 <= 0.09
# |   |   |   |   |   |   |   |   |--- op3 <= 0.07
# |   |   |   |   |   |   |   |   |   |--- op1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |   |   |   |--- op1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.42]
# |   |   |   |   |   |   |   |   |--- op3 >  0.07
# |   |   |   |   |   |   |   |   |   |--- op1 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.81]
# |   |   |   |   |   |   |   |   |   |--- op1 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |   |   |   |   |   |--- aug3 >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.62]
# |   |   |   |   |   |   |   |--- op3 >  0.09
# |   |   |   |   |   |   |   |   |--- aug2 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.14]
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- aug1 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.52]
# |   |   |   |   |   |   |   |   |   |   |--- aug1 >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- aug2 >  0.11
# |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [81.91]
# |   |   |   |   |   |   |   |   |   |--- aug3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [81.22]
# |   |   |   |--- op1 >  0.02
# |   |   |   |   |--- op1 <= 0.09
# |   |   |   |   |   |--- op1 <= 0.02
# |   |   |   |   |   |   |--- op3 <= 0.01
# |   |   |   |   |   |   |   |--- value: [83.86]
# |   |   |   |   |   |   |--- op3 >  0.01
# |   |   |   |   |   |   |   |--- aug3 <= 0.27
# |   |   |   |   |   |   |   |   |--- value: [83.58]
# |   |   |   |   |   |   |   |--- aug3 >  0.27
# |   |   |   |   |   |   |   |   |--- op3 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- value: [83.33]
# |   |   |   |   |   |   |   |   |--- op3 >  0.01
# |   |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |--- op1 >  0.02
# |   |   |   |   |   |   |--- aug3 <= 0.24
# |   |   |   |   |   |   |   |--- aug1 <= 0.64
# |   |   |   |   |   |   |   |   |--- op3 <= 0.04
# |   |   |   |   |   |   |   |   |   |--- aug1 <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- aug1 <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.95]
# |   |   |   |   |   |   |   |   |   |   |--- aug1 >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.59]
# |   |   |   |   |   |   |   |   |   |--- aug1 >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- aug1 <= 0.54
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.04]
# |   |   |   |   |   |   |   |   |   |   |--- aug1 >  0.54
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.38]
# |   |   |   |   |   |   |   |   |--- op3 >  0.04
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.16]
# |   |   |   |   |   |   |   |   |   |   |--- aug3 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.68]
# |   |   |   |   |   |   |   |--- aug1 >  0.64
# |   |   |   |   |   |   |   |   |--- op3 <= 0.07
# |   |   |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |   |   |   |   |--- op3 >  0.07
# |   |   |   |   |   |   |   |   |   |--- value: [81.71]
# |   |   |   |   |   |   |--- aug3 >  0.24
# |   |   |   |   |   |   |   |--- op2 <= 0.21
# |   |   |   |   |   |   |   |   |--- op2 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.77
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |   |   |   |   |   |--- aug2 >  0.77
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |   |--- op2 >  0.01
# |   |   |   |   |   |   |   |   |   |--- op1 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.57]
# |   |   |   |   |   |   |   |   |   |--- op1 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |--- op2 >  0.21
# |   |   |   |   |   |   |   |   |--- aug3 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- aug1 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- aug3 >  0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- aug1 >  0.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.39]
# |   |   |   |   |   |   |   |   |--- aug3 >  0.31
# |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.59
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.91]
# |   |   |   |   |   |   |   |   |   |--- aug3 >  0.59
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |--- op1 >  0.09
# |   |   |   |   |   |--- value: [81.44]
# |   |--- op1 >  0.09
# |   |   |--- aug2 <= 0.94
# |   |   |   |--- aug3 <= 0.40
# |   |   |   |   |--- op1 <= 0.89
# |   |   |   |   |   |--- op2 <= 0.00
# |   |   |   |   |   |   |--- op3 <= -0.04
# |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |   |--- op3 >  -0.04
# |   |   |   |   |   |   |   |--- op2 <= 0.00
# |   |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |   |   |   |--- op2 >  0.00
# |   |   |   |   |   |   |   |   |--- value: [82.40]
# |   |   |   |   |   |--- op2 >  0.00
# |   |   |   |   |   |   |--- aug1 <= 0.12
# |   |   |   |   |   |   |   |--- aug2 <= 0.32
# |   |   |   |   |   |   |   |   |--- op3 <= 0.02
# |   |   |   |   |   |   |   |   |   |--- value: [81.88]
# |   |   |   |   |   |   |   |   |--- op3 >  0.02
# |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |--- aug2 >  0.32
# |   |   |   |   |   |   |   |   |--- op3 <= 0.19
# |   |   |   |   |   |   |   |   |   |--- op2 <= 0.43
# |   |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.43]
# |   |   |   |   |   |   |   |   |   |   |--- aug2 >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- op2 >  0.43
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.83]
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |--- op3 >  0.19
# |   |   |   |   |   |   |   |   |   |--- op2 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.81]
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.83
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.84]
# |   |   |   |   |   |   |   |   |   |--- op2 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.06]
# |   |   |   |   |   |   |--- aug1 >  0.12
# |   |   |   |   |   |   |   |--- aug2 <= 0.10
# |   |   |   |   |   |   |   |   |--- op1 <= 0.10
# |   |   |   |   |   |   |   |   |   |--- value: [81.93]
# |   |   |   |   |   |   |   |   |--- op1 >  0.10
# |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.35
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.01]
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |   |   |   |   |--- aug3 >  0.35
# |   |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.70]
# |   |   |   |   |   |   |   |   |   |   |--- aug3 >  0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.60]
# |   |   |   |   |   |   |   |--- aug2 >  0.10
# |   |   |   |   |   |   |   |   |--- op2 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- op2 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.18]
# |   |   |   |   |   |   |   |   |   |--- op2 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- op3 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.75]
# |   |   |   |   |   |   |   |   |   |   |--- op3 >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.69]
# |   |   |   |   |   |   |   |   |--- op2 >  0.01
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.13]
# |   |   |   |   |   |   |   |   |   |   |--- aug3 >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |--- op1 >  0.89
# |   |   |   |   |   |--- aug1 <= 0.21
# |   |   |   |   |   |   |--- aug2 <= 0.07
# |   |   |   |   |   |   |   |--- aug1 <= 0.12
# |   |   |   |   |   |   |   |   |--- aug2 <= 0.05
# |   |   |   |   |   |   |   |   |   |--- value: [82.89]
# |   |   |   |   |   |   |   |   |--- aug2 >  0.05
# |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |   |   |--- aug1 >  0.12
# |   |   |   |   |   |   |   |   |--- op3 <= 0.04
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.26]
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.00
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- op3 >  0.04
# |   |   |   |   |   |   |   |   |   |--- op1 <= 0.94
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.27]
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.89
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |   |   |   |   |   |--- op1 >  0.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |--- aug2 >  0.07
# |   |   |   |   |   |   |   |--- op2 <= 0.04
# |   |   |   |   |   |   |   |   |--- aug3 <= 0.28
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.40]
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.36]
# |   |   |   |   |   |   |   |   |--- aug3 >  0.28
# |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |   |--- op2 >  0.04
# |   |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |   |   |--- aug1 >  0.21
# |   |   |   |   |   |   |--- value: [82.37]
# |   |   |   |--- aug3 >  0.40
# |   |   |   |   |--- op3 <= 0.09
# |   |   |   |   |   |--- aug2 <= 0.05
# |   |   |   |   |   |   |--- op3 <= 0.02
# |   |   |   |   |   |   |   |--- op2 <= 0.11
# |   |   |   |   |   |   |   |   |--- op2 <= 0.06
# |   |   |   |   |   |   |   |   |   |--- value: [83.46]
# |   |   |   |   |   |   |   |   |--- op2 >  0.06
# |   |   |   |   |   |   |   |   |   |--- op3 <= 0.01
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.90]
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |   |   |   |   |   |--- op3 >  0.01
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.67]
# |   |   |   |   |   |   |   |--- op2 >  0.11
# |   |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |--- op3 >  0.02
# |   |   |   |   |   |   |   |--- op1 <= 0.11
# |   |   |   |   |   |   |   |   |--- aug1 <= 0.88
# |   |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |   |   |--- aug1 >  0.88
# |   |   |   |   |   |   |   |   |   |--- value: [83.10]
# |   |   |   |   |   |   |   |--- op1 >  0.11
# |   |   |   |   |   |   |   |   |--- value: [83.53]
# |   |   |   |   |   |--- aug2 >  0.05
# |   |   |   |   |   |   |--- op3 <= 0.02
# |   |   |   |   |   |   |   |--- aug1 <= 0.50
# |   |   |   |   |   |   |   |   |--- aug3 <= 0.58
# |   |   |   |   |   |   |   |   |   |--- value: [81.83]
# |   |   |   |   |   |   |   |   |--- aug3 >  0.58
# |   |   |   |   |   |   |   |   |   |--- op3 <= -0.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |   |   |   |   |--- op3 >  -0.22
# |   |   |   |   |   |   |   |   |   |   |--- op3 <= -0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |   |   |   |   |   |   |--- op3 >  -0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |--- aug1 >  0.50
# |   |   |   |   |   |   |   |   |--- op2 <= 0.01
# |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |   |--- op2 >  0.01
# |   |   |   |   |   |   |   |   |   |--- aug1 <= 0.76
# |   |   |   |   |   |   |   |   |   |   |--- op2 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.44]
# |   |   |   |   |   |   |   |   |   |   |--- op2 >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.49]
# |   |   |   |   |   |   |   |   |   |--- aug1 >  0.76
# |   |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- aug2 >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- op3 >  0.02
# |   |   |   |   |   |   |   |--- aug3 <= 0.85
# |   |   |   |   |   |   |   |   |--- aug2 <= 0.13
# |   |   |   |   |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |   |   |   |   |--- aug2 >  0.13
# |   |   |   |   |   |   |   |   |   |--- aug2 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |   |   |--- aug2 >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- op1 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- op1 >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.84]
# |   |   |   |   |   |   |   |--- aug3 >  0.85
# |   |   |   |   |   |   |   |   |--- value: [82.26]
# |   |   |   |   |--- op3 >  0.09
# |   |   |   |   |   |--- op3 <= 0.15
# |   |   |   |   |   |   |--- op3 <= 0.12
# |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |   |   |   |--- op3 >  0.12
# |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |--- op3 >  0.15
# |   |   |   |   |   |   |--- aug2 <= 0.58
# |   |   |   |   |   |   |   |--- op1 <= 0.76
# |   |   |   |   |   |   |   |   |--- aug1 <= 0.06
# |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |--- aug1 >  0.06
# |   |   |   |   |   |   |   |   |   |--- aug3 <= 0.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.04]
# |   |   |   |   |   |   |   |   |   |--- aug3 >  0.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |   |   |   |   |--- op1 >  0.76
# |   |   |   |   |   |   |   |   |--- value: [83.50]
# |   |   |   |   |   |   |--- aug2 >  0.58
# |   |   |   |   |   |   |   |--- value: [83.65]
# |   |   |--- aug2 >  0.94
# |   |   |   |--- aug3 <= 0.27
# |   |   |   |   |--- value: [84.10]
# |   |   |   |--- aug3 >  0.27
# |   |   |   |   |--- value: [82.21]
# |--- aug1 >  0.99
# |   |--- value: [84.13]
# /home/noah/.conda/envs/essl/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
#              aug1        op1        aug2       op2            aug3        op3  \
# 0          Rotate  22.000000  TranslateY  2.000000      TranslateX   7.000000
# 1          ShearY   0.126119  Brightness  1.314937  HorizontalFlip   0.603191
# 2    VerticalFlip   0.981939       Color  0.469010          ShearX   0.041533
# 3       Sharpness   0.668222    Solarize  0.428321           Color   0.953488
# 4          ShearX   0.136720       Color  0.443667      TranslateX  10.000000
# ..            ...        ...         ...       ...             ...        ...
# 445  VerticalFlip   0.850476       Color  0.594466          ShearX   0.104604
# 446      Solarize   0.813661  Brightness  0.918928          ShearX   0.126433
# 447  VerticalFlip   0.850476  TranslateY  3.000000      TranslateX   8.000000
# 448        ShearY   0.126119  TranslateY  2.000000          Rotate  -1.000000
# 449        ShearY   0.180383  Brightness  0.690515           Color   0.161926
#
#     seed  test acc
# 0      7     82.84
# 1      7     82.58
# 2      7     82.70
# 3      7     82.68
# 4      7     82.62
# ..   ...       ...
# 445    8     81.44
# 446    8     83.67
# 447    8     83.22
# 448    8     84.24
# 449    8     84.13
#
# [450 rows x 8 columns]

# %% [markdown]
# Considerably worse performance when using as categorical

# %% [markdown]
# # exp 4: fit linear regression and DT regressor to dataset with neutral values

# %%
# apply nuetral values to missing values, everything but solarize has value of 0.0 when not applied. 
neutral = {'Brightness':0.0,
 'Color':0.0,
 'Contrast':0.0,
 'HorizontalFlip':0.0,
 'Rotate':0.0,
 'Sharpness':0.0,
 'ShearX':0.0,
 'ShearY':0.0,
 'Solarize':1.0,
 'TranslateX':0.0,
 'TranslateY':0.0,
 'VerticalFlip':0.0
          }

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.tree import export_text, plot_tree

df_long['Solarize'] = df_long['Solarize'].apply(lambda x: 1.0 if x == 0.0 else x)
X = df_long[ops]
y = df_long["fitness"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=10)
reg = LinearRegression().fit(X_train, y_train)
print("LR score: ", reg.score(X_test, y_test))
coeffs.append(reg.coef_)
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X_train, y_train)
# print(cross_val_score(regressor, X, y, cv=10))
print("DT score: ", regressor.score(X_test, y_test))
regressor.get_depth()
tree = export_text(regressor, feature_names=list(ops))
print(tree)
# Out:
# LR score:  -0.10152499866110687
# DT score:  0.15126819637791444
# |--- Solarize <= 0.61
# |   |--- ShearY <= 0.01
# |   |   |--- Rotate <= 14.00
# |   |   |   |--- Solarize <= 0.56
# |   |   |   |   |--- Solarize <= 0.41
# |   |   |   |   |   |--- VerticalFlip <= 0.49
# |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |--- Contrast <= 1.43
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.37]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- Contrast <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |   |   |   |   |   |   |--- Contrast >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.46]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.69]
# |   |   |   |   |   |   |   |--- Contrast >  1.43
# |   |   |   |   |   |   |   |   |--- value: [84.15]
# |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |   |   |--- Color <= 0.80
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |   |   |--- Color >  0.80
# |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |   |--- value: [83.07]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.03]
# |   |   |   |   |   |--- VerticalFlip >  0.49
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.87]
# |   |   |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.17]
# |   |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |   |--- value: [82.69]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |--- value: [82.19]
# |   |   |   |   |--- Solarize >  0.41
# |   |   |   |   |   |--- TranslateX <= 3.50
# |   |   |   |   |   |   |--- Color <= 0.45
# |   |   |   |   |   |   |   |--- value: [83.15]
# |   |   |   |   |   |   |--- Color >  0.45
# |   |   |   |   |   |   |   |--- TranslateY <= 1.50
# |   |   |   |   |   |   |   |   |--- Sharpness <= 0.33
# |   |   |   |   |   |   |   |   |   |--- value: [82.61]
# |   |   |   |   |   |   |   |   |--- Sharpness >  0.33
# |   |   |   |   |   |   |   |   |   |--- value: [82.68]
# |   |   |   |   |   |   |   |--- TranslateY >  1.50
# |   |   |   |   |   |   |   |   |--- value: [82.38]
# |   |   |   |   |   |--- TranslateX >  3.50
# |   |   |   |   |   |   |--- Solarize <= 0.47
# |   |   |   |   |   |   |   |--- value: [82.04]
# |   |   |   |   |   |   |--- Solarize >  0.47
# |   |   |   |   |   |   |   |--- value: [82.22]
# |   |   |   |--- Solarize >  0.56
# |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |--- value: [83.60]
# |   |   |--- Rotate >  14.00
# |   |   |   |--- value: [81.88]
# |   |--- ShearY >  0.01
# |   |   |--- Color <= 0.22
# |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |--- TranslateY <= 1.00
# |   |   |   |   |   |--- Solarize <= 0.49
# |   |   |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |--- ShearY <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.13]
# |   |   |   |   |   |   |   |   |   |--- ShearY >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.87]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.86]
# |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |--- value: [82.66]
# |   |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |   |--- value: [82.33]
# |   |   |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |   |   |--- Solarize <= 0.33
# |   |   |   |   |   |   |   |   |--- value: [83.07]
# |   |   |   |   |   |   |   |--- Solarize >  0.33
# |   |   |   |   |   |   |   |   |--- value: [82.92]
# |   |   |   |   |   |--- Solarize >  0.49
# |   |   |   |   |   |   |--- TranslateX <= 13.50
# |   |   |   |   |   |   |   |--- value: [81.73]
# |   |   |   |   |   |   |--- TranslateX >  13.50
# |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |--- TranslateY >  1.00
# |   |   |   |   |   |--- value: [82.07]
# |   |   |   |--- ShearY >  0.11
# |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |--- value: [82.74]
# |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |--- value: [82.76]
# |   |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |--- ShearY >  0.16
# |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |--- value: [83.22]
# |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |--- value: [83.11]
# |   |   |--- Color >  0.22
# |   |   |   |--- ShearY <= 0.07
# |   |   |   |   |--- value: [81.51]
# |   |   |   |--- ShearY >  0.07
# |   |   |   |   |--- Solarize <= 0.44
# |   |   |   |   |   |--- Solarize <= 0.26
# |   |   |   |   |   |   |--- value: [82.49]
# |   |   |   |   |   |--- Solarize >  0.26
# |   |   |   |   |   |   |--- value: [82.76]
# |   |   |   |   |--- Solarize >  0.44
# |   |   |   |   |   |--- ShearY <= 0.14
# |   |   |   |   |   |   |--- value: [82.05]
# |   |   |   |   |   |--- ShearY >  0.14
# |   |   |   |   |   |   |--- value: [82.57]
# |--- Solarize >  0.61
# |   |--- ShearY <= 0.12
# |   |   |--- Contrast <= 0.75
# |   |   |   |--- Rotate <= -0.50
# |   |   |   |   |--- Color <= 0.40
# |   |   |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |   |   |--- ShearY <= 0.11
# |   |   |   |   |   |   |   |--- value: [82.93]
# |   |   |   |   |   |   |--- ShearY >  0.11
# |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |   |   |   |--- value: [81.96]
# |   |   |   |   |   |   |--- ShearY >  0.05
# |   |   |   |   |   |   |   |--- value: [82.13]
# |   |   |   |   |--- Color >  0.40
# |   |   |   |   |   |--- VerticalFlip <= 0.52
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.01
# |   |   |   |   |   |   |   |--- value: [82.71]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.01
# |   |   |   |   |   |   |   |--- value: [82.73]
# |   |   |   |   |   |--- VerticalFlip >  0.52
# |   |   |   |   |   |   |--- value: [82.90]
# |   |   |   |--- Rotate >  -0.50
# |   |   |   |   |--- HorizontalFlip <= 0.39
# |   |   |   |   |   |--- HorizontalFlip <= 0.10
# |   |   |   |   |   |   |--- TranslateY <= 0.50
# |   |   |   |   |   |   |   |--- VerticalFlip <= 0.03
# |   |   |   |   |   |   |   |   |--- Color <= 0.44
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- Rotate <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Rotate >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Color >  0.44
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.95
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.82
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.95
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- VerticalFlip >  0.03
# |   |   |   |   |   |   |   |   |--- Brightness <= 0.29
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- Color <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Color >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- Brightness >  0.29
# |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- Brightness <= 0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Brightness >  0.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.93]
# |   |   |   |   |   |   |--- TranslateY >  0.50
# |   |   |   |   |   |   |   |--- ShearX <= 0.15
# |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |--- TranslateX <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.58]
# |   |   |   |   |   |   |   |   |   |   |--- Solarize >  0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- TranslateX >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- Rotate <= 14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [81.83]
# |   |   |   |   |   |   |   |   |   |   |--- Rotate >  14.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.12]
# |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |--- Solarize <= 0.98
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.24]
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82.63]
# |   |   |   |   |   |   |   |   |   |--- Solarize >  0.98
# |   |   |   |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- ShearX >  0.15
# |   |   |   |   |   |   |   |   |--- TranslateY <= 2.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.47]
# |   |   |   |   |   |   |   |   |--- TranslateY >  2.50
# |   |   |   |   |   |   |   |   |   |--- value: [83.94]
# |   |   |   |   |   |--- HorizontalFlip >  0.10
# |   |   |   |   |   |   |--- value: [84.10]
# |   |   |   |   |--- HorizontalFlip >  0.39
# |   |   |   |   |   |--- Solarize <= 0.98
# |   |   |   |   |   |   |--- value: [83.05]
# |   |   |   |   |   |--- Solarize >  0.98
# |   |   |   |   |   |   |--- ShearY <= 0.06
# |   |   |   |   |   |   |   |--- Color <= 0.62
# |   |   |   |   |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.75]
# |   |   |   |   |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |   |   |   |   |--- value: [82.80]
# |   |   |   |   |   |   |   |--- Color >  0.62
# |   |   |   |   |   |   |   |   |--- value: [82.55]
# |   |   |   |   |   |   |--- ShearY >  0.06
# |   |   |   |   |   |   |   |--- Color <= 0.28
# |   |   |   |   |   |   |   |   |--- Color <= 0.06
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.46]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.67]
# |   |   |   |   |   |   |   |   |--- Color >  0.06
# |   |   |   |   |   |   |   |   |   |--- value: [81.91]
# |   |   |   |   |   |   |   |--- Color >  0.28
# |   |   |   |   |   |   |   |   |--- value: [82.63]
# |   |   |--- Contrast >  0.75
# |   |   |   |--- ShearY <= 0.05
# |   |   |   |   |--- Contrast <= 1.18
# |   |   |   |   |   |--- TranslateY <= 1.00
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.31
# |   |   |   |   |   |   |   |--- value: [83.48]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.31
# |   |   |   |   |   |   |   |--- Color <= 0.58
# |   |   |   |   |   |   |   |   |--- value: [83.78]
# |   |   |   |   |   |   |   |--- Color >  0.58
# |   |   |   |   |   |   |   |   |--- value: [83.63]
# |   |   |   |   |   |--- TranslateY >  1.00
# |   |   |   |   |   |   |--- value: [83.12]
# |   |   |   |   |--- Contrast >  1.18
# |   |   |   |   |   |--- TranslateY <= 0.50
# |   |   |   |   |   |   |--- VerticalFlip <= 0.11
# |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |--- Rotate <= 14.00
# |   |   |   |   |   |   |   |   |   |--- Sharpness <= 0.44
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |   |   |   |   |--- VerticalFlip >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83.11]
# |   |   |   |   |   |   |   |   |   |--- Sharpness >  0.44
# |   |   |   |   |   |   |   |   |   |   |--- value: [83.21]
# |   |   |   |   |   |   |   |   |--- Rotate >  14.00
# |   |   |   |   |   |   |   |   |   |--- value: [82.98]
# |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.10
# |   |   |   |   |   |   |   |   |   |--- Color <= 0.66
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |   |   |   |   |   |--- Color >  0.66
# |   |   |   |   |   |   |   |   |   |   |--- value: [82.88]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.10
# |   |   |   |   |   |   |   |   |   |--- value: [83.20]
# |   |   |   |   |   |   |--- VerticalFlip >  0.11
# |   |   |   |   |   |   |   |--- ShearX <= 0.05
# |   |   |   |   |   |   |   |   |--- Contrast <= 1.47
# |   |   |   |   |   |   |   |   |   |--- value: [83.60]
# |   |   |   |   |   |   |   |   |--- Contrast >  1.47
# |   |   |   |   |   |   |   |   |   |--- value: [83.49]
# |   |   |   |   |   |   |   |--- ShearX >  0.05
# |   |   |   |   |   |   |   |   |--- ShearX <= 0.13
# |   |   |   |   |   |   |   |   |   |--- value: [83.28]
# |   |   |   |   |   |   |   |   |--- ShearX >  0.13
# |   |   |   |   |   |   |   |   |   |--- value: [83.02]
# |   |   |   |   |   |--- TranslateY >  0.50
# |   |   |   |   |   |   |--- Contrast <= 1.47
# |   |   |   |   |   |   |   |--- TranslateX <= 4.00
# |   |   |   |   |   |   |   |   |--- value: [83.40]
# |   |   |   |   |   |   |   |--- TranslateX >  4.00
# |   |   |   |   |   |   |   |   |--- value: [82.96]
# |   |   |   |   |   |   |--- Contrast >  1.47
# |   |   |   |   |   |   |   |--- value: [83.70]
# |   |   |   |--- ShearY >  0.05
# |   |   |   |   |--- Color <= 0.22
# |   |   |   |   |   |--- value: [82.84]
# |   |   |   |   |--- Color >  0.22
# |   |   |   |   |   |--- value: [82.26]
# |   |--- ShearY >  0.12
# |   |   |--- TranslateX <= 3.00
# |   |   |   |--- HorizontalFlip <= 0.49
# |   |   |   |   |--- Color <= 0.30
# |   |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |   |--- HorizontalFlip <= 0.23
# |   |   |   |   |   |   |   |--- Brightness <= 1.00
# |   |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |   |--- value: [84.24]
# |   |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |   |--- value: [84.13]
# |   |   |   |   |   |   |   |--- Brightness >  1.00
# |   |   |   |   |   |   |   |   |--- value: [83.37]
# |   |   |   |   |   |   |--- HorizontalFlip >  0.23
# |   |   |   |   |   |   |   |--- Color <= 0.08
# |   |   |   |   |   |   |   |   |--- value: [83.25]
# |   |   |   |   |   |   |   |--- Color >  0.08
# |   |   |   |   |   |   |   |   |--- value: [83.74]
# |   |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |   |--- ShearX <= 0.02
# |   |   |   |   |   |   |   |--- value: [83.14]
# |   |   |   |   |   |   |--- ShearX >  0.02
# |   |   |   |   |   |   |   |--- value: [83.23]
# |   |   |   |   |--- Color >  0.30
# |   |   |   |   |   |--- TranslateY <= 0.50
# |   |   |   |   |   |   |--- ShearY <= 0.18
# |   |   |   |   |   |   |   |--- value: [83.41]
# |   |   |   |   |   |   |--- ShearY >  0.18
# |   |   |   |   |   |   |   |--- value: [83.66]
# |   |   |   |   |   |--- TranslateY >  0.50
# |   |   |   |   |   |   |--- value: [82.14]
# |   |   |   |--- HorizontalFlip >  0.49
# |   |   |   |   |--- ShearY <= 0.16
# |   |   |   |   |   |--- value: [82.79]
# |   |   |   |   |--- ShearY >  0.16
# |   |   |   |   |   |--- value: [82.21]
# |   |   |--- TranslateX >  3.00
# |   |   |   |--- ShearX <= 0.12
# |   |   |   |   |--- Color <= 0.87
# |   |   |   |   |   |--- TranslateX <= 6.50
# |   |   |   |   |   |   |--- value: [82.08]
# |   |   |   |   |   |--- TranslateX >  6.50
# |   |   |   |   |   |   |--- TranslateX <= 10.00
# |   |   |   |   |   |   |   |--- HorizontalFlip <= 0.30
# |   |   |   |   |   |   |   |   |--- value: [82.31]
# |   |   |   |   |   |   |   |--- HorizontalFlip >  0.30
# |   |   |   |   |   |   |   |   |--- value: [82.35]
# |   |   |   |   |   |   |--- TranslateX >  10.00
# |   |   |   |   |   |   |   |--- value: [82.42]
# |   |   |   |   |--- Color >  0.87
# |   |   |   |   |   |--- value: [82.97]
# |   |   |   |--- ShearX >  0.12
# |   |   |   |   |--- value: [83.33]

# %% [markdown]
# We do not see any improvement chanigng solarize to 1 instead of zero... this is expected.

# %%
df = pd.DataFrame(coeffs, columns = ops)
df

# %%
exps = ["/home/noah/ESSL/exps/iteration4/exp6_0", "/home/noah/ESSL/exps/iteration4/exp6_1"]
chromos = []
for e_i in exps:
    exps_i = glob.glob(os.path.join(exp_dir, "*/"))
    for e in exps_i:
        seed = e.split("/")[-2]
        with open(os.path.join(e, "outcomes.json"), "r") as f:
            results = json.load(f)
            for fitness, chromo in zip(results["pop_vals"], results["chromos"]):
                c = list(chain.from_iterable(chromo[1]))
                c.append(e_i.split("/")[-1])
                c.append(seed)
                c.append(fitness[1])
                chromos.append(c)
columns = list(chain.from_iterable([[f"aug{i}", f"op{i}"] for i in range(1, 4)]))
columns.append("experiment")
columns.append("seed")
columns.append("test acc")
columns

df = pd.DataFrame(chromos, columns=columns)
df
# Out:
#              aug1        op1        aug2       op2            aug3        op3  \
# 0          Rotate  22.000000  TranslateY  2.000000      TranslateX   7.000000
# 1          ShearY   0.126119  Brightness  1.314937  HorizontalFlip   0.603191
# 2    VerticalFlip   0.981939       Color  0.469010          ShearX   0.041533
# 3       Sharpness   0.668222    Solarize  0.428321           Color   0.953488
# 4          ShearX   0.136720       Color  0.443667      TranslateX  10.000000
# ..            ...        ...         ...       ...             ...        ...
# 895  VerticalFlip   0.850476       Color  0.594466          ShearX   0.104604
# 896      Solarize   0.813661  Brightness  0.918928          ShearX   0.126433
# 897  VerticalFlip   0.850476  TranslateY  3.000000      TranslateX   8.000000
# 898        ShearY   0.126119  TranslateY  2.000000          Rotate  -1.000000
# 899        ShearY   0.180383  Brightness  0.690515           Color   0.161926
#
#     experiment seed  test acc
# 0       exp6_0    7     82.84
# 1       exp6_0    7     82.58
# 2       exp6_0    7     82.70
# 3       exp6_0    7     82.68
# 4       exp6_0    7     82.62
# ..         ...  ...       ...
# 895     exp6_1    8     81.44
# 896     exp6_1    8     83.67
# 897     exp6_1    8     83.22
# 898     exp6_1    8     84.24
# 899     exp6_1    8     84.13
#
# [900 rows x 9 columns]
